# %%
import os
from dotenv import load_dotenv; load_dotenv()

from tqdm.notebook import tqdm
import pickle
import pandas as pd
import polars as pl
import numpy as np
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import json

os.environ["PYTORCH_MPS_HIGH_WATERMARK_RATIO"] = "0.0"
import torch
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity

from src.helpers import preprocessing as preproc
from src.helpers.postprocessing import get_top_k_representative_docs, from_list_to_string, safe_json_load
from src.helpers.sentiment_analysis import SentimentModel
from src.topol_modeling import TopolModeling as TOPOL
from sknetwork.clustering import Leiden
from scipy.sparse import csr_matrix
from src.openai_api import OPENAI_CLIENT, OpenAIEmbedding
from src.openai_api import chat_completion as openai_chat_completion
from src.google_ai_api import GGENAI_CLIENT, GoogleAIEmbedding, AdvancedGoogleAIEmbedding
from src.google_ai_api import chat_completion as google_chat_completion

# %%
DATA_PATH = os.getenv("DATA_PATH")
OUTPUTS_PATH = os.path.join(os.getenv("OUTPUTS_PATH"), "robustness_checks", "rb1")

DEVICE = torch.device("mps")
STOP_WORDS = list(ENGLISH_STOP_WORDS)
RANDOM_STATE = 42

# %% [markdown]
# ---
#
# # Getting data

# %%
df = pd.read_pickle(os.path.join(DATA_PATH, "us_fed_speeches.pickle"))
FILES_PREFIX = "us_speeches"

# %%
# breakpoint = pd.to_datetime("2007-05-01")

# df["label"] = 1.0
# df.loc[df["date"] <= breakpoint, "label"] = 0

# %%
print(len(df[df["label"] == 0]), len(df[df["label"] == 1]))
df
# Out:
# 333 267
#           date                                               text  label
# 0   2004-01-03  Ben S Bernanke: Fedspeak\nSpeech by Mr Ben S B...    0.0
# 1   2004-01-03  Ben S Bernanke: Conducting monetary policy at ...    0.0
# 2   2004-01-03  Alan Greenspan: Risk and uncertainty in moneta...    0.0
# 3   2004-01-04  Ben S Bernanke: Monetary policy and the econom...    0.0
# 4   2004-01-04  Roger W Ferguson, Jr: Lessons from past produc...    0.0
# ..         ...                                                ...    ...
# 595 2010-03-25  Ben S Bernanke: Federal Reserve's exit strateg...    1.0
# 596 2010-03-26  Daniel K Tarullo: Lessons from the crisis stre...    1.0
# 597 2010-03-26  Kevin Warsh: An ode to independence\nSpeech by...    1.0
# 598 2010-03-26  Brian P Sack: Dollar asset markets - prospects...    1.0
# 599 2010-03-31  Elizabeth A Duke: Restoring credit to communit...    1.0
#
# [600 rows x 3 columns]

# %%
word_counts = df["text"].apply(lambda x: len(x.split()))
q1_word_counts = word_counts.quantile(0.25)
q2_word_counts = word_counts.quantile(0.50)
avg_word_counts = word_counts.mean()
q3_word_counts = word_counts.quantile(0.75)
q4_word_counts = word_counts.quantile(0.95)
plt.figure(figsize=(10, 5))
plt.hist(word_counts, bins=50, color='blue', alpha=0.7)
plt.axvline(q1_word_counts, color='red', linestyle='dashed', linewidth=1, label=f'Q1: {q1_word_counts:.2f}')
plt.axvline(q2_word_counts, color='green', linestyle='dashed', linewidth=1, label=f'Q2: {q2_word_counts:.2f}')
plt.axvline(avg_word_counts, color='orange', linestyle='dashed', linewidth=1, label=f'Avg: {avg_word_counts:.2f}')
plt.axvline(q3_word_counts, color='purple', linestyle='dashed', linewidth=1, label=f'Q3: {q3_word_counts:.2f}')
plt.axvline(q4_word_counts, color='brown', linestyle='dashed', linewidth=1, label=f'Q4: {q4_word_counts:.2f}')
plt.legend()
plt.xlabel("Word Count")
plt.ylabel("Frequency")
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# ---
#
# # Pre-processing data

# %% [markdown]
# ##### 1. Data cleaning

# %%
entities_to_mask = ["DATE", "TIME", "ORGANIZATION", "NUM", "LOCATION"]
STOP_WORDS += entities_to_mask

fpath = os.path.join(DATA_PATH, f"{FILES_PREFIX}_texts.pickle")
if os.path.exists(fpath):
    print(f"Loading cleaned texts from {fpath}")
    with open(fpath, "rb") as f:
        texts = pickle.load(f)
    print(f"Loaded {len(texts)} texts")
else:
    print(f"Generating cleaned texts for {len(df)} raw texts...")
    texts = []
    for i, row in tqdm(df.iterrows(), total=len(df)):
        cleaned_text = preproc.get_clean_text(row, entities_to_mask=entities_to_mask, max_lenght=5000)
        texts.append(cleaned_text)
    with open(fpath, "wb") as f:
        pickle.dump(texts, f)
    print(f"Saved {len(texts)} cleaned texts to {fpath}.")

df["text"] = texts
del fpath
# Out:
# Loading cleaned texts from /Users/tig1/Programming/TOPOL/data/us_speeches_texts.pickle
# Loaded 600 texts

# %% [markdown]
# ##### 2. Embedding texts

# %%
EMBEDDING_MODEL = OpenAIEmbedding(model="text-embedding-3-small")
# EMBEDDING_MODEL = GoogleAIEmbedding(model="text-embedding-004")
# EMBEDDING_MODEL = AdvancedGoogleAIEmbedding(model='text-embedding-004', task='clustering')
# EMBEDDING_MODEL = SentenceTransformer('intfloat/multilingual-e5-large-instruct', device=DEVICE)

fpath = os.path.join(DATA_PATH, f"{FILES_PREFIX}_embeddings.pickle")
if os.path.exists(fpath):
    print(f"Loading embeddings from {fpath}")
    with open(fpath, "rb") as f:
        embeddings = pickle.load(f)
    print(f"Loaded {len(embeddings)} embeddings")
else:
    print(f"Generating embeddings for {len(df)} text...")
    embeddings = EMBEDDING_MODEL.encode(df["text"].tolist(), fast=False)
    with open(fpath, "wb") as f:
        pickle.dump(embeddings, f)
    print(f"Saved {len(embeddings)} embeddings to {fpath}.")

df["embedding"] = embeddings.tolist()
del fpath
# Out:
# Loading embeddings from /Users/tig1/Programming/TOPOL/data/us_speeches_embeddings.pickle
# Loaded 600 embeddings

# %% [markdown]
# ##### 3.a. Sentiment Analysis: FinBERT

# %%
sentiment_model = SentimentModel(model_name="ProsusAI/finbert", device=DEVICE, n_special_tokens=5)

fpath = os.path.join(DATA_PATH, f"{FILES_PREFIX}_sentiments_finbert.pickle")
if os.path.exists(fpath):
    print(f"Loading sentiments from {fpath}")
    with open(fpath, "rb") as f:
        sentiments = pickle.load(f)
    print(f"Loaded {len(sentiments)} sentiments")
else:
    print(f"Generating sentiments for {len(df)} texts...")
    sentiments = []
    for idx, row in tqdm(df.iterrows(), total=len(df)):
        doc = row['text']
        temp_sentiment = sentiment_model(doc, truncation=False)
        sentiments.append(temp_sentiment)
    with open(fpath, "wb") as f:
        pickle.dump(sentiments, f)
    print(f"Saved {len(sentiments)} sentiments to {fpath}.")

df["sentiment_finbert"] = sentiments
df["sentiment_score_finbert"] = df["sentiment_finbert"].apply(sentiment_model.get_sentiment_score)
del fpath, sentiment_model
# Out:
# Device set to use mps
# Loading sentiments from /Users/tig1/Programming/TOPOL/data/us_speeches_sentiments_finbert.pickle
# Loaded 600 sentiments

# %% [markdown]
# ##### 3.b. Sentiment Analysis: Multilingual DistilBERT

# %%
sentiment_model = SentimentModel(model_name="tabularisai/multilingual-sentiment-analysis", device=DEVICE, n_special_tokens=5)

fpath = os.path.join(DATA_PATH, f"{FILES_PREFIX}_sentiments_distilbert.pickle")
if os.path.exists(fpath):
    print(f"Loading sentiments from {fpath}")
    with open(fpath, "rb") as f:
        sentiments = pickle.load(f)
    print(f"Loaded {len(sentiments)} sentiments")
else:
    print(f"Generating sentiments for {len(df)} texts...")
    sentiments = []
    for idx, row in tqdm(df.iterrows(), total=len(df)):
        doc = row['text']
        temp_sentiment = sentiment_model(doc, truncation=False)
        sentiments.append(temp_sentiment)
    with open(fpath, "wb") as f:
        pickle.dump(sentiments, f)
    print(f"Saved {len(sentiments)} sentiments to {fpath}.")

df["sentiment_distilbert"] = sentiments
df["sentiment_score_distilbert"] = df["sentiment_distilbert"].apply(sentiment_model.get_sentiment_score)
del fpath, sentiment_model
# Out:
# Device set to use mps
# Loading sentiments from /Users/tig1/Programming/TOPOL/data/us_speeches_sentiments_distilbert.pickle
# Loaded 600 sentiments

# %% [markdown]
# # TOPol Modeling

# %% [markdown]
# ### Create TOPol model object

# %%
umap_params = {
    'n_neighbors': 100,
    'min_dist': 0.0,
    'metric': 'cosine', # do not change this
}

leiden_params = {
    'resolution': 1.5,
    'modularity': 'dugue', # do not change this
}

topol_model = TOPOL(
    # n_components=50, --- IGNORE ---
    n_components=75, # Robustness check 1: Increase dimensionality
    umap_model_params=umap_params,
    leiden_model_params=leiden_params,
    random_state=RANDOM_STATE,
)

# %% [markdown]
# ### Fit TOPol model

# %%
df = pl.from_pandas(df)
topol_model.fit(df)
# Out:
# UMAP applied successfully.
# Leiden clustering applied successfully.

# %% [markdown]
# ### Default setup analysis

# %%
cb0_cluster_info, cb1_cluster_info = topol_model.get_cluster_info(label_col="label")

# %%
cb0_cluster_info
# Out:
# shape: (11, 9)
# ┌─────────┬──────┬──────────┬─────────────┬───┬─────────────┬────────────┬────────────┬────────────┐
# │ cluster ┆ size ┆ avg_prob ┆ centroid    ┆ … ┆ 2D_centroid ┆ cosine_dis ┆ l2_dispers ┆ dot_produc │
# │ ---     ┆ ---  ┆ ---      ┆ ---         ┆   ┆ ---         ┆ persion    ┆ ion        ┆ t_dispersi │
# │ i32     ┆ i32  ┆ f64      ┆ array[f64,  ┆   ┆ array[f64,  ┆ ---        ┆ ---        ┆ on         │
# │         ┆      ┆          ┆ 1536]       ┆   ┆ 2]          ┆ f64        ┆ f64        ┆ ---        │
# │         ┆      ┆          ┆             ┆   ┆             ┆            ┆            ┆ f64        │
# ╞═════════╪══════╪══════════╪═════════════╪═══╪═════════════╪════════════╪════════════╪════════════╡
# │ 0       ┆ 52   ┆ 0.694262 ┆ [-0.003069, ┆ … ┆ [0.423915,  ┆ 0.171865   ┆ 0.554721   ┆ 0.314193   │
# │         ┆      ┆          ┆ 0.001461, … ┆   ┆ 6.183156]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.013…     ┆   ┆             ┆            ┆            ┆            │
# │ 1       ┆ 63   ┆ 0.765139 ┆ [0.009838,  ┆ … ┆ [-1.261685, ┆ 0.146609   ┆ 0.509861   ┆ 0.271725   │
# │         ┆      ┆          ┆ 0.019493, … ┆   ┆ 7.051733]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0118…    ┆   ┆             ┆            ┆            ┆            │
# │ 2       ┆ 26   ┆ 0.577826 ┆ [0.006046,  ┆ … ┆ [2.388209,  ┆ 0.138554   ┆ 0.500284   ┆ 0.257911   │
# │         ┆      ┆          ┆ 0.020238, … ┆   ┆ 9.478988]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0028…    ┆   ┆             ┆            ┆            ┆            │
# │ 3       ┆ 47   ┆ 0.675644 ┆ [0.011792,  ┆ … ┆ [-1.156859, ┆ 0.173903   ┆ 0.556278   ┆ 0.317564   │
# │         ┆      ┆          ┆ 0.017663, … ┆   ┆ 5.33152]    ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0088…    ┆   ┆             ┆            ┆            ┆            │
# │ 4       ┆ 48   ┆ 0.794425 ┆ [0.021526,  ┆ … ┆ [4.106255,  ┆ 0.15333    ┆ 0.526036   ┆ 0.28315    │
# │         ┆      ┆          ┆ 0.026192, … ┆   ┆ 9.365142]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.00024…    ┆   ┆             ┆            ┆            ┆            │
# │ …       ┆ …    ┆ …        ┆ …           ┆ … ┆ …           ┆ …          ┆ …          ┆ …          │
# │ 6       ┆ 11   ┆ 0.473553 ┆ [0.000117,  ┆ … ┆ [2.656012,  ┆ 0.140061   ┆ 0.507723   ┆ 0.260505   │
# │         ┆      ┆          ┆ 0.008739, … ┆   ┆ 8.459787]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0020…    ┆   ┆             ┆            ┆            ┆            │
# │ 7       ┆ 16   ┆ 0.627282 ┆ [0.033481,  ┆ … ┆ [0.569662,  ┆ 0.180895   ┆ 0.568385   ┆ 0.329068   │
# │         ┆      ┆          ┆ 0.014835, … ┆   ┆ 9.122775]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0090…    ┆   ┆             ┆            ┆            ┆            │
# │ 8       ┆ 31   ┆ 0.581838 ┆ [0.024037,  ┆ … ┆ [-1.414603, ┆ 0.213078   ┆ 0.614043   ┆ 0.380754   │
# │         ┆      ┆          ┆ 0.012686, … ┆   ┆ 5.962382]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0062…    ┆   ┆             ┆            ┆            ┆            │
# │ 9       ┆ 23   ┆ 0.532122 ┆ [0.014811,  ┆ … ┆ [1.793944,  ┆ 0.16422    ┆ 0.544803   ┆ 0.301471   │
# │         ┆      ┆          ┆ 0.014586, … ┆   ┆ 8.27058]    ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.00128…    ┆   ┆             ┆            ┆            ┆            │
# │ 10      ┆ 14   ┆ 0.453511 ┆ [-0.005508, ┆ … ┆ [1.476161,  ┆ 0.1922     ┆ 0.583335   ┆ 0.347459   │
# │         ┆      ┆          ┆ -0.013746,  ┆   ┆ 7.224054]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ … -0.00…    ┆   ┆             ┆            ┆            ┆            │
# └─────────┴──────┴──────────┴─────────────┴───┴─────────────┴────────────┴────────────┴────────────┘

# %%
cb0_cluster_info
# Out:
# shape: (11, 9)
# ┌─────────┬──────┬──────────┬─────────────┬───┬─────────────┬────────────┬────────────┬────────────┐
# │ cluster ┆ size ┆ avg_prob ┆ centroid    ┆ … ┆ 2D_centroid ┆ cosine_dis ┆ l2_dispers ┆ dot_produc │
# │ ---     ┆ ---  ┆ ---      ┆ ---         ┆   ┆ ---         ┆ persion    ┆ ion        ┆ t_dispersi │
# │ i32     ┆ i32  ┆ f64      ┆ array[f64,  ┆   ┆ array[f64,  ┆ ---        ┆ ---        ┆ on         │
# │         ┆      ┆          ┆ 1536]       ┆   ┆ 2]          ┆ f64        ┆ f64        ┆ ---        │
# │         ┆      ┆          ┆             ┆   ┆             ┆            ┆            ┆ f64        │
# ╞═════════╪══════╪══════════╪═════════════╪═══╪═════════════╪════════════╪════════════╪════════════╡
# │ 0       ┆ 52   ┆ 0.694262 ┆ [-0.003069, ┆ … ┆ [0.423915,  ┆ 0.171865   ┆ 0.554721   ┆ 0.314193   │
# │         ┆      ┆          ┆ 0.001461, … ┆   ┆ 6.183156]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.013…     ┆   ┆             ┆            ┆            ┆            │
# │ 1       ┆ 63   ┆ 0.765139 ┆ [0.009838,  ┆ … ┆ [-1.261685, ┆ 0.146609   ┆ 0.509861   ┆ 0.271725   │
# │         ┆      ┆          ┆ 0.019493, … ┆   ┆ 7.051733]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0118…    ┆   ┆             ┆            ┆            ┆            │
# │ 2       ┆ 26   ┆ 0.577826 ┆ [0.006046,  ┆ … ┆ [2.388209,  ┆ 0.138554   ┆ 0.500284   ┆ 0.257911   │
# │         ┆      ┆          ┆ 0.020238, … ┆   ┆ 9.478988]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0028…    ┆   ┆             ┆            ┆            ┆            │
# │ 3       ┆ 47   ┆ 0.675644 ┆ [0.011792,  ┆ … ┆ [-1.156859, ┆ 0.173903   ┆ 0.556278   ┆ 0.317564   │
# │         ┆      ┆          ┆ 0.017663, … ┆   ┆ 5.33152]    ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0088…    ┆   ┆             ┆            ┆            ┆            │
# │ 4       ┆ 48   ┆ 0.794425 ┆ [0.021526,  ┆ … ┆ [4.106255,  ┆ 0.15333    ┆ 0.526036   ┆ 0.28315    │
# │         ┆      ┆          ┆ 0.026192, … ┆   ┆ 9.365142]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.00024…    ┆   ┆             ┆            ┆            ┆            │
# │ …       ┆ …    ┆ …        ┆ …           ┆ … ┆ …           ┆ …          ┆ …          ┆ …          │
# │ 6       ┆ 11   ┆ 0.473553 ┆ [0.000117,  ┆ … ┆ [2.656012,  ┆ 0.140061   ┆ 0.507723   ┆ 0.260505   │
# │         ┆      ┆          ┆ 0.008739, … ┆   ┆ 8.459787]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0020…    ┆   ┆             ┆            ┆            ┆            │
# │ 7       ┆ 16   ┆ 0.627282 ┆ [0.033481,  ┆ … ┆ [0.569662,  ┆ 0.180895   ┆ 0.568385   ┆ 0.329068   │
# │         ┆      ┆          ┆ 0.014835, … ┆   ┆ 9.122775]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0090…    ┆   ┆             ┆            ┆            ┆            │
# │ 8       ┆ 31   ┆ 0.581838 ┆ [0.024037,  ┆ … ┆ [-1.414603, ┆ 0.213078   ┆ 0.614043   ┆ 0.380754   │
# │         ┆      ┆          ┆ 0.012686, … ┆   ┆ 5.962382]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0062…    ┆   ┆             ┆            ┆            ┆            │
# │ 9       ┆ 23   ┆ 0.532122 ┆ [0.014811,  ┆ … ┆ [1.793944,  ┆ 0.16422    ┆ 0.544803   ┆ 0.301471   │
# │         ┆      ┆          ┆ 0.014586, … ┆   ┆ 8.27058]    ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.00128…    ┆   ┆             ┆            ┆            ┆            │
# │ 10      ┆ 14   ┆ 0.453511 ┆ [-0.005508, ┆ … ┆ [1.476161,  ┆ 0.1922     ┆ 0.583335   ┆ 0.347459   │
# │         ┆      ┆          ┆ -0.013746,  ┆   ┆ 7.224054]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ … -0.00…    ┆   ┆             ┆            ┆            ┆            │
# └─────────┴──────┴──────────┴─────────────┴───┴─────────────┴────────────┴────────────┴────────────┘

# %%
fig, ax = topol_model.visualize(label_col="label")
fig.savefig(os.path.join(OUTPUTS_PATH, f"{FILES_PREFIX}_default_topol_clusters.pdf"), format="pdf", bbox_inches='tight')
plt.show(fig, ax)
# Out:
# Drift computed successfully, ready to visualize.

# %% [markdown]
# ### Randomized contextual boundary analysis

# %%
random_cb0_cluster_info, random_cb1_cluster_info = topol_model.get_cluster_info(label_col="random_label")

# %%
random_cb0_cluster_info
# Out:
# shape: (11, 9)
# ┌─────────┬──────┬──────────┬─────────────┬───┬─────────────┬────────────┬────────────┬────────────┐
# │ cluster ┆ size ┆ avg_prob ┆ centroid    ┆ … ┆ 2D_centroid ┆ cosine_dis ┆ l2_dispers ┆ dot_produc │
# │ ---     ┆ ---  ┆ ---      ┆ ---         ┆   ┆ ---         ┆ persion    ┆ ion        ┆ t_dispersi │
# │ i32     ┆ i32  ┆ f64      ┆ array[f64,  ┆   ┆ array[f64,  ┆ ---        ┆ ---        ┆ on         │
# │         ┆      ┆          ┆ 1536]       ┆   ┆ 2]          ┆ f64        ┆ f64        ┆ ---        │
# │         ┆      ┆          ┆             ┆   ┆             ┆            ┆            ┆ f64        │
# ╞═════════╪══════╪══════════╪═════════════╪═══╪═════════════╪════════════╪════════════╪════════════╡
# │ 0       ┆ 52   ┆ 0.686957 ┆ [-0.008636, ┆ … ┆ [0.428125,  ┆ 0.168094   ┆ 0.549767   ┆ 0.307933   │
# │         ┆      ┆          ┆ 0.003784, … ┆   ┆ 6.201116]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.013…     ┆   ┆             ┆            ┆            ┆            │
# │ 1       ┆ 48   ┆ 0.746086 ┆ [0.007768,  ┆ … ┆ [-1.145001, ┆ 0.131075   ┆ 0.480593   ┆ 0.244969   │
# │         ┆      ┆          ┆ 0.018167, … ┆   ┆ 7.015736]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0114…    ┆   ┆             ┆            ┆            ┆            │
# │ 2       ┆ 32   ┆ 0.551105 ┆ [0.005654,  ┆ … ┆ [1.823105,  ┆ 0.142924   ┆ 0.512251   ┆ 0.265421   │
# │         ┆      ┆          ┆ 0.02286, …  ┆   ┆ 9.407274]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.00902…   ┆   ┆             ┆            ┆            ┆            │
# │ 3       ┆ 39   ┆ 0.661239 ┆ [0.01011,   ┆ … ┆ [-1.146237, ┆ 0.173587   ┆ 0.55553    ┆ 0.317042   │
# │         ┆      ┆          ┆ 0.020093, … ┆   ┆ 5.379249]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.00692…   ┆   ┆             ┆            ┆            ┆            │
# │ 4       ┆ 25   ┆ 0.826528 ┆ [0.015584,  ┆ … ┆ [4.215139,  ┆ 0.146616   ┆ 0.511399   ┆ 0.271736   │
# │         ┆      ┆          ┆ 0.024967, … ┆   ┆ 9.352228]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.00061…    ┆   ┆             ┆            ┆            ┆            │
# │ …       ┆ …    ┆ …        ┆ …           ┆ … ┆ …           ┆ …          ┆ …          ┆ …          │
# │ 6       ┆ 23   ┆ 0.577475 ┆ [0.006243,  ┆ … ┆ [2.50254,   ┆ 0.122092   ┆ 0.471115   ┆ 0.229277   │
# │         ┆      ┆          ┆ 0.017124, … ┆   ┆ 8.852202]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.00144…    ┆   ┆             ┆            ┆            ┆            │
# │ 7       ┆ 27   ┆ 0.635245 ┆ [0.0239,    ┆ … ┆ [0.745717,  ┆ 0.166097   ┆ 0.547977   ┆ 0.304605   │
# │         ┆      ┆          ┆ 0.027151, … ┆   ┆ 9.294074]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.014217…  ┆   ┆             ┆            ┆            ┆            │
# │ 8       ┆ 23   ┆ 0.540098 ┆ [0.023606,  ┆ … ┆ [-1.218506, ┆ 0.230282   ┆ 0.631938   ┆ 0.407534   │
# │         ┆      ┆          ┆ 0.008617, … ┆   ┆ 6.058489]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0041…    ┆   ┆             ┆            ┆            ┆            │
# │ 9       ┆ 21   ┆ 0.511971 ┆ [0.010097,  ┆ … ┆ [1.430922,  ┆ 0.163954   ┆ 0.53982    ┆ 0.301028   │
# │         ┆      ┆          ┆ 0.014814, … ┆   ┆ 8.424171]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.00198…    ┆   ┆             ┆            ┆            ┆            │
# │ 10      ┆ 16   ┆ 0.388361 ┆ [-0.01316,  ┆ … ┆ [1.603575,  ┆ 0.189613   ┆ 0.578846   ┆ 0.343272   │
# │         ┆      ┆          ┆ -0.005536,  ┆   ┆ 7.347378]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ … -0.004…   ┆   ┆             ┆            ┆            ┆            │
# └─────────┴──────┴──────────┴─────────────┴───┴─────────────┴────────────┴────────────┴────────────┘

# %%
random_cb1_cluster_info
# Out:
# shape: (11, 9)
# ┌─────────┬──────┬──────────┬─────────────┬───┬─────────────┬────────────┬────────────┬────────────┐
# │ cluster ┆ size ┆ avg_prob ┆ centroid    ┆ … ┆ 2D_centroid ┆ cosine_dis ┆ l2_dispers ┆ dot_produc │
# │ ---     ┆ ---  ┆ ---      ┆ ---         ┆   ┆ ---         ┆ persion    ┆ ion        ┆ t_dispersi │
# │ i32     ┆ i32  ┆ f64      ┆ array[f64,  ┆   ┆ array[f64,  ┆ ---        ┆ ---        ┆ on         │
# │         ┆      ┆          ┆ 1536]       ┆   ┆ 2]          ┆ f64        ┆ f64        ┆ ---        │
# │         ┆      ┆          ┆             ┆   ┆             ┆            ┆            ┆ f64        │
# ╞═════════╪══════╪══════════╪═════════════╪═══╪═════════════╪════════════╪════════════╪════════════╡
# │ 0       ┆ 32   ┆ 0.674923 ┆ [0.000643,  ┆ … ┆ [0.484068,  ┆ 0.171086   ┆ 0.553966   ┆ 0.312901   │
# │         ┆      ┆          ┆ -0.000625,  ┆   ┆ 6.245398]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ … -0.010…   ┆   ┆             ┆            ┆            ┆            │
# │ 1       ┆ 36   ┆ 0.732963 ┆ [0.011668,  ┆ … ┆ [-1.128772, ┆ 0.135374   ┆ 0.491812   ┆ 0.252421   │
# │         ┆      ┆          ┆ 0.018825, … ┆   ┆ 7.162407]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0127…    ┆   ┆             ┆            ┆            ┆            │
# │ 2       ┆ 31   ┆ 0.581713 ┆ [0.003512,  ┆ … ┆ [1.860088,  ┆ 0.158229   ┆ 0.53366    ┆ 0.291421   │
# │         ┆      ┆          ┆ 0.021466, … ┆   ┆ 9.466473]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0051…    ┆   ┆             ┆            ┆            ┆            │
# │ 3       ┆ 19   ┆ 0.652878 ┆ [0.006522,  ┆ … ┆ [-1.047514, ┆ 0.166175   ┆ 0.548212   ┆ 0.304736   │
# │         ┆      ┆          ┆ 0.012908, … ┆   ┆ 5.285162]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0115…    ┆   ┆             ┆            ┆            ┆            │
# │ 4       ┆ 30   ┆ 0.768613 ┆ [0.02459,   ┆ … ┆ [4.023815,  ┆ 0.158332   ┆ 0.536635   ┆ 0.291594   │
# │         ┆      ┆          ┆ 0.028661, … ┆   ┆ 9.386045]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.000485…   ┆   ┆             ┆            ┆            ┆            │
# │ …       ┆ …    ┆ …        ┆ …           ┆ … ┆ …           ┆ …          ┆ …          ┆ …          │
# │ 6       ┆ 28   ┆ 0.586319 ┆ [0.003815,  ┆ … ┆ [2.605797,  ┆ 0.148868   ┆ 0.520382   ┆ 0.275574   │
# │         ┆      ┆          ┆ 0.009471, … ┆   ┆ 8.820437]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.00218…    ┆   ┆             ┆            ┆            ┆            │
# │ 7       ┆ 23   ┆ 0.658912 ┆ [0.026372,  ┆ … ┆ [0.505511,  ┆ 0.181626   ┆ 0.567904   ┆ 0.330264   │
# │         ┆      ┆          ┆ 0.025148, … ┆   ┆ 9.361402]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0209…    ┆   ┆             ┆            ┆            ┆            │
# │ 8       ┆ 14   ┆ 0.594249 ┆ [0.025578,  ┆ … ┆ [-1.499886, ┆ 0.212284   ┆ 0.611053   ┆ 0.379503   │
# │         ┆      ┆          ┆ 0.008673, … ┆   ┆ 5.865988]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ -0.0108…    ┆   ┆             ┆            ┆            ┆            │
# │ 9       ┆ 14   ┆ 0.502725 ┆ [0.011727,  ┆ … ┆ [1.604024,  ┆ 0.165798   ┆ 0.549727   ┆ 0.304107   │
# │         ┆      ┆          ┆ 0.009934, … ┆   ┆ 8.121208]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ 0.00009…    ┆   ┆             ┆            ┆            ┆            │
# │ 10      ┆ 15   ┆ 0.47308  ┆ [0.005062,  ┆ … ┆ [1.448367,  ┆ 0.187289   ┆ 0.578336   ┆ 0.339501   │
# │         ┆      ┆          ┆ -0.008267,  ┆   ┆ 7.356877]   ┆            ┆            ┆            │
# │         ┆      ┆          ┆ … -0.009…   ┆   ┆             ┆            ┆            ┆            │
# └─────────┴──────┴──────────┴─────────────┴───┴─────────────┴────────────┴────────────┴────────────┘

# %%
fig, ax = topol_model.visualize(label_col="random_label")
fig.savefig(os.path.join(OUTPUTS_PATH, f"{FILES_PREFIX}_random_cb_topol_clusters.pdf"), format="pdf", bbox_inches='tight')
plt.show(fig, ax)
# Out:
# Drift computed successfully, ready to visualize.

# %% [markdown]
# ### Drift analysis

# %%
assert cb0_cluster_info["cluster"].to_list() == cb1_cluster_info["cluster"].to_list(), "Cluster IDs are not the same for C.B.-0 and C.B.-1"
clusters = cb0_cluster_info["cluster"].to_list()

# %%
drifts_default = {}
for cluster_id, cb0_centroid, cb1_centroid in zip(clusters, cb0_cluster_info["centroid"].to_list(), cb1_cluster_info["centroid"].to_list()):
    drifts_default[cluster_id] = np.array(cb1_centroid) - np.array(cb0_centroid)

# %%
pairwise_drift_similarity = cosine_similarity(
    np.stack(list(drifts_default.values())), 
    np.stack(list(drifts_default.values()))
)
# pairwise_drift_similarity = pd.DataFrame(np.triu(pairwise_drift_similarity, k=1))
triu_indices = np.triu_indices(pairwise_drift_similarity.shape[0], k=1)
pairwise_drift_similarity = pairwise_drift_similarity[triu_indices[0], triu_indices[1]]

pairwise_drift_similarity.min(), pairwise_drift_similarity.mean(), pairwise_drift_similarity.max()
# Out:
# (np.float64(-0.08568218417775507),
#  np.float64(0.1313700575286087),
#  np.float64(0.39609095125334876))

# %%
drift_norms = np.linalg.norm(np.stack(list(drifts_default.values())), axis=1)
drift_norms.min(), drift_norms.mean(), drift_norms.max()
# Out:
# (np.float64(0.12906361515958206),
#  np.float64(0.2925434979163051),
#  np.float64(0.4305229875119968))

# %%
drifts_random_cb = {}
for cluster_id, cb0_centroid, cb1_centroid in zip(clusters, random_cb0_cluster_info["centroid"].to_list(), random_cb1_cluster_info["centroid"].to_list()):
    drifts_random_cb[cluster_id] = np.array(cb1_centroid) - np.array(cb0_centroid)

# %%
pairwise_drift_similarity = cosine_similarity(
    np.stack(list(drifts_random_cb.values())), 
    np.stack(list(drifts_random_cb.values()))
)
# pairwise_drift_similarity = pd.DataFrame(np.triu(pairwise_drift_similarity, k=1))
triu_indices = np.triu_indices(pairwise_drift_similarity.shape[0], k=1)
pairwise_drift_similarity = pairwise_drift_similarity[triu_indices[0], triu_indices[1]]

pairwise_drift_similarity.min(), pairwise_drift_similarity.mean(), pairwise_drift_similarity.max()
# Out:
# (np.float64(-0.2580717592261001),
#  np.float64(-0.009818817075141645),
#  np.float64(0.14625958468688996))

# %%
drift_norms = np.linalg.norm(np.stack(list(drifts_random_cb.values())), axis=1)
drift_norms.min(), drift_norms.mean(), drift_norms.max()
# Out:
# (np.float64(0.10615946690621655),
#  np.float64(0.16724535048362232),
#  np.float64(0.25324864263742075))

# %%
drift_similarities = {}
for cluster_id in clusters:
    drift_default = drifts_default[cluster_id]
    drift_random = drifts_random_cb[cluster_id]
    norm_ratio = np.linalg.norm(drift_default) / np.linalg.norm(drift_random)
    similarity = cosine_similarity([drift_default], [drift_random])[0][0]
    dot_prod = np.dot(drift_default, drift_random)
    drift_similarities[cluster_id] = {
        "cosine_similarity": similarity,
        "dot_product": dot_prod,
        "norm_ratio": norm_ratio
    }
pd.DataFrame(drift_similarities).T
# Out:
#     cosine_similarity  dot_product  norm_ratio
# 0           -0.191875    -0.003248    0.984039
# 1           -0.112763    -0.002656    2.089698
# 2           -0.193761    -0.007789    2.185995
# 3            0.170253     0.006248    1.365421
# 4           -0.170384    -0.006018    1.705290
# 5           -0.110504    -0.006861    2.985370
# 6           -0.287765    -0.015965    2.296822
# 7           -0.218238    -0.011153    2.083766
# 8           -0.167521    -0.016039    1.866027
# 9           -0.300355    -0.022158    1.484614
# 10          -0.049742    -0.002947    0.923657

# %%
norm_ratios = [drift_similarities[cluster_id]["norm_ratio"] for cluster_id in clusters]
plt.figure(figsize=(10, 5))
plt.bar(clusters, norm_ratios, color='blue', alpha=0.7)
plt.xlabel('Cluster ID')
plt.ylabel('Norm Ratio')
plt.title('Norm Ratios of Drifts for Each Cluster')
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.75)
# plt.savefig(os.path.join(OUTPUTS_PATH, f"{FILES_PREFIX}_norm_ratios.pdf"), format="pdf", bbox_inches='tight')
print(np.mean(norm_ratios), np.std(norm_ratios))
plt.show()
# Out:
# 1.8155181657483688 0.5798237836667606

# %%
# Norm ratio entropy
norm_ratios = np.array(norm_ratios)
norm_ratios = norm_ratios / np.sum(norm_ratios)
norm_ratio_entropy = -np.sum(norm_ratios * np.log(norm_ratios + 1e-10)) / np.log(len(norm_ratios))  # Adding a small value to avoid log(0) and normalizing by log(len(norm_ratios))
print(f"Norm Ratio Entropy: {norm_ratio_entropy}")
# Out:
# Norm Ratio Entropy: 0.9782476804440613

# %% [markdown]
# ### Comparing with sentiment

# %%
cb0_df = topol_model.df.filter(pl.col("label") == 0)
sentiment_cb0_cluster_info = cb0_df.group_by("cluster")\
    .map_groups(lambda group: pl.DataFrame({
        "cluster": group["cluster"][0],
        "sentiment_score_finbert": np.mean(group["sentiment_score_finbert"].to_list(), axis=0),
        "sentiment_score_distilbert": np.mean(group["sentiment_score_distilbert"].to_list(), axis=0),
    }))
sentiment_cb0_cluster_info.mean()
# Out:
# shape: (1, 3)
# ┌─────────┬─────────────────────────┬────────────────────────────┐
# │ cluster ┆ sentiment_score_finbert ┆ sentiment_score_distilbert │
# │ ---     ┆ ---                     ┆ ---                        │
# │ f64     ┆ f64                     ┆ f64                        │
# ╞═════════╪═════════════════════════╪════════════════════════════╡
# │ 5.0     ┆ 0.075102                ┆ 0.100722                   │
# └─────────┴─────────────────────────┴────────────────────────────┘

# %%
cb1_df = topol_model.df.filter(pl.col("label") == 1)
sentiment_cb1_cluster_info = cb1_df.group_by("cluster")\
    .map_groups(lambda group: pl.DataFrame({
        "cluster": group["cluster"][0],
        "sentiment_score_finbert": np.mean(group["sentiment_score_finbert"].to_list(), axis=0),
        "sentiment_score_distilbert": np.mean(group["sentiment_score_distilbert"].to_list(), axis=0),
    }))
sentiment_cb1_cluster_info.mean()
# Out:
# shape: (1, 3)
# ┌─────────┬─────────────────────────┬────────────────────────────┐
# │ cluster ┆ sentiment_score_finbert ┆ sentiment_score_distilbert │
# │ ---     ┆ ---                     ┆ ---                        │
# │ f64     ┆ f64                     ┆ f64                        │
# ╞═════════╪═════════════════════════╪════════════════════════════╡
# │ 5.0     ┆ -0.003754               ┆ 0.049852                   │
# └─────────┴─────────────────────────┴────────────────────────────┘

# %%
random_cb0_df = topol_model.df.filter(pl.col("random_label") == 0)
random_sentiment_cb0_cluster_info = random_cb0_df.group_by("cluster")\
    .map_groups(lambda group: pl.DataFrame({
        "cluster": group["cluster"][0],
        "sentiment_score_finbert": np.mean(group["sentiment_score_finbert"].to_list(), axis=0),
        "sentiment_score_distilbert": np.mean(group["sentiment_score_distilbert"].to_list(), axis=0),
    }))
random_sentiment_cb0_cluster_info.mean()
# Out:
# shape: (1, 3)
# ┌─────────┬─────────────────────────┬────────────────────────────┐
# │ cluster ┆ sentiment_score_finbert ┆ sentiment_score_distilbert │
# │ ---     ┆ ---                     ┆ ---                        │
# │ f64     ┆ f64                     ┆ f64                        │
# ╞═════════╪═════════════════════════╪════════════════════════════╡
# │ 5.0     ┆ 0.034494                ┆ 0.043694                   │
# └─────────┴─────────────────────────┴────────────────────────────┘

# %%
random_cb1_df = topol_model.df.filter(pl.col("random_label") == 1)
random_sentiment_cb1_cluster_info = random_cb1_df.group_by("cluster")\
    .map_groups(lambda group: pl.DataFrame({
        "cluster": group["cluster"][0],
        "sentiment_score_finbert": np.mean(group["sentiment_score_finbert"].to_list(), axis=0),
        "sentiment_score_distilbert": np.mean(group["sentiment_score_distilbert"].to_list(), axis=0),
    }))
random_sentiment_cb1_cluster_info.mean()
# Out:
# shape: (1, 3)
# ┌─────────┬─────────────────────────┬────────────────────────────┐
# │ cluster ┆ sentiment_score_finbert ┆ sentiment_score_distilbert │
# │ ---     ┆ ---                     ┆ ---                        │
# │ f64     ┆ f64                     ┆ f64                        │
# ╞═════════╪═════════════════════════╪════════════════════════════╡
# │ 5.0     ┆ 0.031192                ┆ 0.068814                   │
# └─────────┴─────────────────────────┴────────────────────────────┘

# %% [markdown]
# ### Quality metrics

# %%
cb0_cluster_info[["size", "avg_prob", "cosine_dispersion", "l2_dispersion", "dot_product_dispersion"]].mean()
# Out:
# shape: (1, 5)
# ┌───────────┬──────────┬───────────────────┬───────────────┬────────────────────────┐
# │ size      ┆ avg_prob ┆ cosine_dispersion ┆ l2_dispersion ┆ dot_product_dispersion │
# │ ---       ┆ ---      ┆ ---               ┆ ---           ┆ ---                    │
# │ f64       ┆ f64      ┆ f64               ┆ f64           ┆ f64                    │
# ╞═══════════╪══════════╪═══════════════════╪═══════════════╪════════════════════════╡
# │ 30.272727 ┆ 0.606088 ┆ 0.158863          ┆ 0.530907      ┆ 0.291278               │
# └───────────┴──────────┴───────────────────┴───────────────┴────────────────────────┘

# %%
random_cb0_cluster_info[["size", "avg_prob", "cosine_dispersion", "l2_dispersion", "dot_product_dispersion"]].mean()
# Out:
# shape: (1, 5)
# ┌───────────┬──────────┬───────────────────┬───────────────┬────────────────────────┐
# │ size      ┆ avg_prob ┆ cosine_dispersion ┆ l2_dispersion ┆ dot_product_dispersion │
# │ ---       ┆ ---      ┆ ---               ┆ ---           ┆ ---                    │
# │ f64       ┆ f64      ┆ f64               ┆ f64           ┆ f64                    │
# ╞═══════════╪══════════╪═══════════════════╪═══════════════╪════════════════════════╡
# │ 30.272727 ┆ 0.607456 ┆ 0.160587          ┆ 0.533522      ┆ 0.29451                │
# └───────────┴──────────┴───────────────────┴───────────────┴────────────────────────┘

# %%
cb1_cluster_info[["size", "avg_prob", "cosine_dispersion", "l2_dispersion", "dot_product_dispersion"]].mean()
# Out:
# shape: (1, 5)
# ┌───────────┬──────────┬───────────────────┬───────────────┬────────────────────────┐
# │ size      ┆ avg_prob ┆ cosine_dispersion ┆ l2_dispersion ┆ dot_product_dispersion │
# │ ---       ┆ ---      ┆ ---               ┆ ---           ┆ ---                    │
# │ f64       ┆ f64      ┆ f64               ┆ f64           ┆ f64                    │
# ╞═══════════╪══════════╪═══════════════════╪═══════════════╪════════════════════════╡
# │ 24.272727 ┆ 0.583759 ┆ 0.149843          ┆ 0.51619       ┆ 0.275923               │
# └───────────┴──────────┴───────────────────┴───────────────┴────────────────────────┘

# %%
random_cb1_cluster_info[["size", "avg_prob", "cosine_dispersion", "l2_dispersion", "dot_product_dispersion"]].mean()
# Out:
# shape: (1, 5)
# ┌───────────┬──────────┬───────────────────┬───────────────┬────────────────────────┐
# │ size      ┆ avg_prob ┆ cosine_dispersion ┆ l2_dispersion ┆ dot_product_dispersion │
# │ ---       ┆ ---      ┆ ---               ┆ ---           ┆ ---                    │
# │ f64       ┆ f64      ┆ f64               ┆ f64           ┆ f64                    │
# ╞═══════════╪══════════╪═══════════════════╪═══════════════╪════════════════════════╡
# │ 24.272727 ┆ 0.616766 ┆ 0.163665          ┆ 0.541027      ┆ 0.299932               │
# └───────────┴──────────┴───────────────────┴───────────────┴────────────────────────┘

# %% [markdown]
# ### Drift explainability

# %%
XAI_OUTPUTS_PATH = os.path.join(OUTPUTS_PATH, "explainability")

# %% [markdown]
# ##### NRC-VAD Clusters based analysis

# %%
XAI1_PATH = os.path.join(XAI_OUTPUTS_PATH, "nrc_vad_clusters")

# %%
version = "v2.1"  # "v1.0" or "v2.1"
fbase = "NRC-VAD-Lexicon-" + version

nrc_vad_df_path = os.path.join(DATA_PATH, fbase, f"nrc_vad_lexicon_{version}.pkl")
if os.path.exists(nrc_vad_df_path):
    print(f"Loading NRC-VAD lexicon from {nrc_vad_df_path}")
    nrc_vad_df = pd.read_pickle(nrc_vad_df_path) # Pandas DataFrame
else:
    print("File not found.")

nrc_vad_df = pl.DataFrame(nrc_vad_df)
# Out:
# Loading NRC-VAD lexicon from /Users/tig1/Programming/TOPOL/data/NRC-VAD-Lexicon-v2.1/nrc_vad_lexicon_v2.1.pkl

# %%
nrc_vad_embeddings = np.stack(nrc_vad_df["embedding"].to_numpy())
nrc_vad_graph = topol_model.umap_graph.transform(nrc_vad_embeddings)
nrc_vad_adjacency_matrix = csr_matrix(nrc_vad_graph)
nrc_vad_reduced_embeddings = topol_model.umap_dim_reducer.transform(nrc_vad_embeddings)

leiden = Leiden(resolution=2.0, modularity='dugue', random_state=RANDOM_STATE)
leiden.fit(nrc_vad_adjacency_matrix)
nrc_vad_labels = leiden.fit_predict(nrc_vad_adjacency_matrix)
nrc_vad_probs = [probs[cluster_id] for cluster_id, probs in zip(nrc_vad_labels, leiden.predict_proba(False))]

nrc_vad_df = nrc_vad_df.with_columns(
    pl.Series("reduced_embedding", nrc_vad_reduced_embeddings.tolist()),
    pl.Series("cluster", nrc_vad_labels),
    pl.Series("cluster_prob", nrc_vad_probs),
)

# %%
nrcvad_cluster_info = (
    nrc_vad_df.group_by("cluster")
    .map_groups(lambda group: pl.DataFrame({
        "cluster": group["cluster"][0],
        "avg_prob": [np.mean(group["cluster_prob"].to_list())],
        "cluster_size": group.height,
        "terms": [group["term"]],
        "centroid": [np.mean(group["embedding"].to_list(), axis=0)],
        "reduced_centroid": [np.mean(group["reduced_embedding"].to_list(), axis=0)],
        "avg_valence": group["valence"].mean(),
        "avg_arousal": group["arousal"].mean(),
        "avg_dominance": group["dominance"].mean(),
    }))
)
nrcvad_cluster_info = nrcvad_cluster_info.sort("cluster")

# %%
nrcvad_centroids = np.stack(nrcvad_cluster_info["centroid"].to_numpy())
nrcvad_centroids.shape
# Out:
# (35, 1536)

# %% [markdown]
# HoTL proposed contextual boundary

# %%
closest_nrc_vad_cluster_ids = []
valence_values = []
arousal_values = []
dominance_values = []
for row in cb0_cluster_info.iter_rows(named=True):
    centroid = row["centroid"]
    similarities = cosine_similarity([centroid], nrcvad_centroids)[0]
    closest_nrc_vad_cluster_id = int(np.argmax(similarities))
    closest_nrc_vad_cluster_ids.append(closest_nrc_vad_cluster_id)
    nrc_vad_row = nrcvad_cluster_info.filter(pl.col("cluster") == closest_nrc_vad_cluster_id).to_pandas().iloc[0]
    valence_values.append(nrc_vad_row["avg_valence"])
    arousal_values.append(nrc_vad_row["avg_arousal"])
    dominance_values.append(nrc_vad_row["avg_dominance"])

cb0_cluster_info = cb0_cluster_info.with_columns(
    pl.Series("closest_nrc_vad_cluster_id", closest_nrc_vad_cluster_ids),
    pl.Series("valence", valence_values, dtype=pl.Float64),
    pl.Series("arousal", arousal_values, dtype=pl.Float64),
    pl.Series("dominance", dominance_values, dtype=pl.Float64)
)

# %%
closest_nrc_vad_cluster_ids = []
valence_values = []
arousal_values = []
dominance_values = []
for row in cb1_cluster_info.iter_rows(named=True):
    centroid = row["centroid"]
    similarities = cosine_similarity([centroid], nrcvad_centroids)[0]
    closest_nrc_vad_cluster_id = int(np.argmax(similarities))
    closest_nrc_vad_cluster_ids.append(closest_nrc_vad_cluster_id)
    nrc_vad_row = nrcvad_cluster_info.filter(pl.col("cluster") == closest_nrc_vad_cluster_id).to_pandas().iloc[0]
    valence_values.append(nrc_vad_row["avg_valence"])
    arousal_values.append(nrc_vad_row["avg_arousal"])
    dominance_values.append(nrc_vad_row["avg_dominance"])

cb1_cluster_info = cb1_cluster_info.with_columns(
    pl.Series("closest_nrc_vad_cluster_id", closest_nrc_vad_cluster_ids),
    pl.Series("valence", valence_values, dtype=pl.Float64),
    pl.Series("arousal", arousal_values, dtype=pl.Float64),
    pl.Series("dominance", dominance_values, dtype=pl.Float64)
)

# %%
cb0_cluster_info[["valence", "arousal", "dominance"]].mean()
# Out:
# shape: (1, 3)
# ┌──────────┬──────────┬───────────┐
# │ valence  ┆ arousal  ┆ dominance │
# │ ---      ┆ ---      ┆ ---       │
# │ f64      ┆ f64      ┆ f64       │
# ╞══════════╪══════════╪═══════════╡
# │ 0.088451 ┆ 0.006461 ┆ 0.086363  │
# └──────────┴──────────┴───────────┘

# %%
cb1_cluster_info[["valence", "arousal", "dominance"]].mean()
# Out:
# shape: (1, 3)
# ┌──────────┬──────────┬───────────┐
# │ valence  ┆ arousal  ┆ dominance │
# │ ---      ┆ ---      ┆ ---       │
# │ f64      ┆ f64      ┆ f64       │
# ╞══════════╪══════════╪═══════════╡
# │ 0.006621 ┆ 0.044644 ┆ 0.061629  │
# └──────────┴──────────┴───────────┘

# %%
(cb1_cluster_info[["valence", "arousal", "dominance"]] - cb0_cluster_info[["valence", "arousal", "dominance"]]).to_pandas().plot()
# Out:
# <Axes: >

# %%
cb0_cluster_info["closest_nrc_vad_cluster_id"].unique().to_list(), cb1_cluster_info["closest_nrc_vad_cluster_id"].unique().to_list()
# Out:
# ([0, 1, 3, 4, 7, 9, 13, 17, 21, 26], [0, 2, 3, 4, 5, 6, 9, 12, 13, 21])

# %% [markdown]
# Random contextual boundary

# %%
closest_nrc_vad_cluster_ids = []
valence_values = []
arousal_values = []
dominance_values = []
for row in random_cb0_cluster_info.iter_rows(named=True):
    centroid = row["centroid"]
    similarities = cosine_similarity([centroid], nrcvad_centroids)[0]
    closest_nrc_vad_cluster_id = int(np.argmax(similarities))
    closest_nrc_vad_cluster_ids.append(closest_nrc_vad_cluster_id)
    nrc_vad_row = nrcvad_cluster_info.filter(pl.col("cluster") == closest_nrc_vad_cluster_id).to_pandas().iloc[0]
    valence_values.append(nrc_vad_row["avg_valence"])
    arousal_values.append(nrc_vad_row["avg_arousal"])
    dominance_values.append(nrc_vad_row["avg_dominance"])

random_cb0_cluster_info = random_cb0_cluster_info.with_columns(
    pl.Series("closest_nrc_vad_cluster_id", closest_nrc_vad_cluster_ids),
    pl.Series("valence", valence_values, dtype=pl.Float64),
    pl.Series("arousal", arousal_values, dtype=pl.Float64),
    pl.Series("dominance", dominance_values, dtype=pl.Float64)
)

# %%
closest_nrc_vad_cluster_ids = []
valence_values = []
arousal_values = []
dominance_values = []
for row in random_cb1_cluster_info.iter_rows(named=True):
    centroid = row["centroid"]
    similarities = cosine_similarity([centroid], nrcvad_centroids)[0]
    closest_nrc_vad_cluster_id = int(np.argmax(similarities))
    closest_nrc_vad_cluster_ids.append(closest_nrc_vad_cluster_id)
    nrc_vad_row = nrcvad_cluster_info.filter(pl.col("cluster") == closest_nrc_vad_cluster_id).to_pandas().iloc[0]
    valence_values.append(nrc_vad_row["avg_valence"])
    arousal_values.append(nrc_vad_row["avg_arousal"])
    dominance_values.append(nrc_vad_row["avg_dominance"])

random_cb1_cluster_info = random_cb1_cluster_info.with_columns(
    pl.Series("closest_nrc_vad_cluster_id", closest_nrc_vad_cluster_ids),
    pl.Series("valence", valence_values, dtype=pl.Float64),
    pl.Series("arousal", arousal_values, dtype=pl.Float64),
    pl.Series("dominance", dominance_values, dtype=pl.Float64)
)

# %%
random_cb0_cluster_info[["valence", "arousal", "dominance"]].mean()
# Out:
# shape: (1, 3)
# ┌─────────┬──────────┬───────────┐
# │ valence ┆ arousal  ┆ dominance │
# │ ---     ┆ ---      ┆ ---       │
# │ f64     ┆ f64      ┆ f64       │
# ╞═════════╪══════════╪═══════════╡
# │ 0.05772 ┆ 0.037687 ┆ 0.095345  │
# └─────────┴──────────┴───────────┘

# %%
random_cb1_cluster_info[["valence", "arousal", "dominance"]].mean()
# Out:
# shape: (1, 3)
# ┌──────────┬──────────┬───────────┐
# │ valence  ┆ arousal  ┆ dominance │
# │ ---      ┆ ---      ┆ ---       │
# │ f64      ┆ f64      ┆ f64       │
# ╞══════════╪══════════╪═══════════╡
# │ 0.055609 ┆ 0.009037 ┆ 0.073797  │
# └──────────┴──────────┴───────────┘

# %%
(random_cb1_cluster_info[["valence", "arousal", "dominance"]] - random_cb0_cluster_info[["valence", "arousal", "dominance"]]).to_pandas().plot()
# Out:
# <Axes: >

# %%
random_cb0_cluster_info["closest_nrc_vad_cluster_id"].unique().to_list(), random_cb1_cluster_info["closest_nrc_vad_cluster_id"].unique().to_list()
# Out:
# ([0, 1, 4, 5, 9, 12, 13, 17, 21, 26], [0, 3, 4, 5, 6, 7, 9, 11, 13, 21, 26])

# %% [markdown]
# ##### LLM-Generated Approach

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 assert False
#
# AssertionError:

# %%
XAI2_PATH = os.path.join(XAI_OUTPUTS_PATH, "llm_generated")

# %%
fpath = os.path.join(DATA_PATH, "prompt_template.txt")
if os.path.exists(fpath):
    with open(fpath, "r") as f:
        PROMPT_TEMPLATE = f.read()
    print(f"Loaded prompt template from {fpath}")
else:
    raise FileNotFoundError(f"Prompt template file not found at {fpath}")
del fpath
# Out:
# Loaded prompt template from /Users/tig1/Programming/TOPOL/data/prompt_template.txt

# %%
def generate_narrative_comparison_prompt(text1, text2):
    prompt = PROMPT_TEMPLATE.replace("#####TEXT1#####", text1)
    prompt = prompt.replace("#####TEXT2#####", text2)
    return prompt

# %%
# chat_completion_func, model_name = openai_chat_completion, "gpt-4o-mini-2024-07-18"
chat_completion_func, model_name = google_chat_completion, "gemini-2.0-flash"

text_generation_params = {
    "model": model_name,
    "temperature": 0.1,
    "top_p": 1.0,
    # "presence_penalty": 0.0,
    # "frequency_penalty": 0.0,
    "max_tokens": 1000000,
}

K = 5  # Number of top documents to retrieve for each cluster

# %% [markdown]
# HoTL proposed contextual boundary

# %%
cb0_df = topol_model.df.filter(pl.col("label") == 0).clone()
top_k_docs = get_top_k_representative_docs(cb0_cluster_info, cb0_df, k=K)
cb0_cluster_info = cb0_cluster_info.join(top_k_docs, on="cluster", how="left")

# %%
cb1_df = topol_model.df.filter(pl.col("label") == 1).clone()
top_k_docs = get_top_k_representative_docs(cb1_cluster_info, cb1_df, k=K)
cb1_cluster_info = cb1_cluster_info.join(top_k_docs, on="cluster", how="left")

# %%
for cluster_id in tqdm(clusters, desc="Processing clusters"):
    cb0_row = cb0_cluster_info.filter(pl.col("cluster") == cluster_id).to_dicts()[0]
    cb1_row = cb1_cluster_info.filter(pl.col("cluster") == cluster_id).to_dicts()[0]

    # Generate the prompt for the LLM
    text1 = from_list_to_string(cb0_row["top_docs"])
    text2 = from_list_to_string(cb1_row["top_docs"])
    prompt = generate_narrative_comparison_prompt(text1, text2)
    response = chat_completion_func(prompt, **text_generation_params)

    # Parse the JSON response safely
    parsed_llm_out = safe_json_load(response)

    # Save to file
    fname = f"{FILES_PREFIX}_HoTL_cluster_{cluster_id}.json"
    fpath = os.path.join(XAI2_PATH, fname)
    with open(fpath, "w", encoding="utf-8") as f:
        json.dump(parsed_llm_out, f, ensure_ascii=False, indent=2)
# Out:
# Processing clusters:   0%|          | 0/11 [00:00<?, ?it/s]
# Response: ```json
# [
#   {
#     "dimension_title": "Emphasis on Historical Analysis to Focus on Current Challenges",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 3,
#     "confidence_score_text2": 2,
#     "text1_evidence_sentences": [
#       "I do not intend this brief and necessarily incomplete review of events to illustrate how far we have come or to despair of how far we have to go.",
#       "The risk-management approach has gained greater traction as a consequence of the step-up in globalization and the technological changes of DATE, which found us adjusting to events without the comfort of relevant history to guide us."
#     ],
#     "text2_evidence_sentences": [
#       "That subject is the focus of my talk DATE.",
#       "I will organize my remarks around the following two questions: First, what aspects of the existing literature in monetary economics have been particularly helpful in formulating the course of monetary policy since the onset of the financial crisis?"
#     ],
#     "text1_keywords": ["brief and necessarily incomplete review of events", "relevant history to guide us"],
#     "text2_keywords": ["subject is the focus", "formulating the course of monetary policy"]
#   },
#   {
#     "dimension_title": "Acknowledging Inevitable Uncertainty to Seeking Greater Clarity",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 4,
#     "confidence_score_text2": 2,
#     "text1_evidence_sentences": [
#       "Rather, I believe it demonstrates the inevitable and ongoing uncertainty faced by policymakers.",
#       "Given our inevitably incomplete knowledge about key structural aspects of an ever-changing economy and the sometimes asymmetric costs or benefits of particular outcomes, the paradigm on which we have settled has come to involve, at its core, crucial elements of risk management."
#     ],
#     "text2_evidence_sentences": [
#       "I would like to talk about the challenges that lie at the intersection of monetary policy and financial stability.",
#       "The questions I want to address are, first, how should we take account of financial stability in the conduct of monetary policy - for example, should financial stability be another specific responsibility of monetary policy, in addition to its responsibilities for promoting maximum employment and stable prices?"
#     ],
#     "text1_keywords": ["inevitable and ongoing uncertainty", "incomplete knowledge"],
#     "text2_keywords": ["challenges that lie", "take account of financial stability"]
#   },
#   {
#     "dimension_title": "Acceptance of Model Limitations to Striving for Model Improvement",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 4,
#     "confidence_score_text2": 2,
#     "text1_evidence_sentences": [
#       "Every model, no matter how detailed or how well conceived, designed, and implemented, is a vastly simplified representation of the world, with all of the intricacies we experience on a day-to-day basis.",
#       "Formal models are a necessary, but not sufficient, system of analysis."
#     ],
#     "text2_evidence_sentences": [
#       "Second, what are the gaps in this literature that have become particularly evident since the onset of the financial crisis and, therefore, would be fruitful directions for further research that could contribute to the effective design and conduct of monetary policy?",
#       "We need your work to organize our thoughts and guide our judgments about the lessons from this experience."
#     ],
#     "text1_keywords": ["vastly simplified representation", "not sufficient"],
#     "text2_keywords": ["gaps in this literature", "fruitful directions for further research"]
#   },
#   {
#     "dimension_title": "Focus on Aggregate Data to Emphasis on Financial Sector Dynamics",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_score_text1": 4,
#     "confidence_label_text2": "Medium",
#     "confidence_score_text2": 2,
#     "text1_evidence_sentences": [
#       "In the absence of a single variable, or at most a few, that can serve as a reliable guide, policymakers have been forced to fall back on an approach that entails the interpretation of the full range of economic and financial data.",
#       "Policy is implemented through nominal and, implicitly, real short-term interest rates."
#     ],
#     "text2_evidence_sentences": [
#       "A characteristic of the recent crisis, however, was the critical role of interactions within the financial sector.",
#       "Recent research has begun to augment core monetary models with heterogeneous agents, multiple interest rates, and risky lending, but even so, it has become obvious that research on the importance of intermediation and supply constraints on credit provision and thus on spending has lagged significantly."
#     ],
#     "text1_keywords": ["full range of economic and financial data", "short-term interest rates"],
#     "text2_keywords": ["interactions within the financial sector", "heterogeneous agents"]
#   },
#   {
#     "dimension_title": "Reliance on Central Bank Actions to Emphasis on Market Participants' Role",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 4,
#     "confidence_score_text2": 2,
#     "text1_evidence_sentences": [
#       "Enhanced flexibility provides the advantage of allowing the economy to adjust automatically, reducing the reliance on the actions of monetary and other policymakers, which have often come too late or been misguided.",
#       "Indeed, the Federal Reserve under Paul Volcker's leadership starting in DATE did the very heavy lifting against inflation."
#     ],
#     "text2_evidence_sentences": [
#       "Private financial institutions should raise substantial capital, reconstitute business models, and take other actions to reinvigorate the principal transmission channel of monetary policy.",
#       "We at the Fed have taken action to help foster this curative process to improve the real economy, but market participants will ultimately determine its speed and success."
#     ],
#     "text1_keywords": ["actions of monetary and other policymakers", "heavy lifting"],
#     "text2_keywords": ["private financial institutions", "market participants will ultimately determine"]
#   }
# ]
# ```
# Tokens used: 43500
# Cost of the request: $0.000087
# Response: ```json
# [
#   {
#     "dimension_title": "Confidence to Concern",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 16,
#     "confidence_score_text2": 20,
#     "text1_evidence_sentences": [
#       "All told, prospects for ongoing gains in consumer spending and business investment appear good, and the recent indicators are positive.",
#       "In conclusion, Mr. Chairman, despite the challenges that I have highlighted and the many I have not, the U.S. economy has remained on a firm footing, and inflation continues to be well contained."
#     ],
#     "text2_evidence_sentences": [
#       "Clearly, the U.S. economy is going through a very difficult period.",
#       "However, financial markets and financial institutions remain under considerable stress, and cumulative declines in asset prices, tight credit conditions, and high levels of risk aversion continue to weigh on the economy."
#     ],
#     "text1_keywords": ["prospects for ongoing gains", "remained on a firm footing"],
#     "text2_keywords": ["very difficult period", "considerable stress"]
#   },
#   {
#     "dimension_title": "Focus on Growth to Focus on Financial Stability",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 16,
#     "confidence_score_text2": 20,
#     "text1_evidence_sentences": [
#       "At our DATE meeting, we indicated that some additional tightening may be necessary to keep the risks to the attainment of both sustainable economic growth and price stability roughly in balance.",
#       "Thus, the future path for the target federal funds rate will depend importantly on how incoming information on economic activity and inflation affect our assessment of these risks."
#     ],
#     "text2_evidence_sentences": [
#       "Well-functioning financial markets are essential for the efficacy of monetary policy and, indeed, for economic growth and stability.",
#       "To improve market liquidity and market functioning, and consistent with its role as the nation's central bank, the Federal Reserve has supplemented its longstanding discount window by establishing three new facilities for lending to depository institutions and primary dealers."
#     ],
#     "text1_keywords": ["sustainable economic growth", "economic activity"],
#     "text2_keywords": ["financial markets", "market liquidity"]
#   },
#   {
#     "dimension_title": "Measured Pace to Aggressive Action",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 16,
#     "confidence_score_text2": 20,
#     "text1_evidence_sentences": [
#       "During much of that time, we described our actions as \"removing accommodation\" at a \"measured pace.\"",
#       "The FOMC has raised the target federal funds rate NUM basis points at each of the past fifteen meetings over roughly DATE."
#     ],
#     "text2_evidence_sentences": [
#       "In response to deterioration in the near-term outlook for the economy and intensified strains in financial markets, in DATE the Federal Reserve has eased monetary policy substantially further and taken strong actions to increase market liquidity.",
#       "By DATE, the Federal Open Market Committee (FOMC) had brought its target for the federal funds rate to a historically low range of NUM to NUM/NUM percent, where it remains DATE."
#     ],
#     "text1_keywords": ["measured pace", "removing accommodation"],
#     "text2_keywords": ["strong actions", "eased monetary policy"]
#   },
#   {
#     "dimension_title": "Inflation Focus to Growth Focus",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 16,
#     "confidence_score_text2": 20,
#     "text1_evidence_sentences": [
#       "At our DATE meeting, we indicated that some additional tightening may be necessary to keep the risks to the attainment of both sustainable economic growth and price stability roughly in balance.",
#       "Thus, the future path for the target federal funds rate will depend importantly on how incoming information on economic activity and inflation affect our assessment of these risks."
#     ],
#     "text2_evidence_sentences": [
#       "As the Committee noted in its most recent post-meeting statement, we anticipate that these actions, together with the steps we have taken to foster market liquidity, will help to promote growth over time and to mitigate the risks to economic activity.",
#       "Monetary policy has responded proactively to evolving conditions."
#     ],
#     "text1_keywords": ["price stability", "inflation"],
#     "text2_keywords": ["promote growth", "economic activity"]
#   }
# ]
# ```
# Tokens used: 29820
# Cost of the request: $0.000060
# Response: ```json
# [
#   {
#     "dimension_title": "Uncertainty to Confidence",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 11,
#     "text1_evidence_sentences": [
#       "Although a complete understanding of the reasons remains elusive, globalization and innovation would appear to be essential elements of any paradigm capable of explaining the events of DATE.",
#       "But because so much of our recent experience has little precedent, as I noted earlier, we cannot fully determine how long the current globalization dynamic will take to play out."
#     ],
#     "text2_evidence_sentences": [
#       "The improvements in the conduct of monetary policy were critical to the improvements in productivity and growth that we are now seeing on a global scale.",
#       "And monetary policy will, of course, continue to be critical, but monetary policy alone cannot provide the elements of the framework necessary to provide an environment for innovation and long-term decisions that will be so vital for future growth."
#     ],
#     "text1_keywords": ["understanding remains elusive", "cannot fully determine"],
#     "text2_keywords": ["critical", "necessary"]
#   },
#   {
#     "dimension_title": "Worry to Reassurance",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 11,
#     "text1_evidence_sentences": [
#       "The resolution of our current account deficit and household debt burdens does not strike me as overly worrisome, but that is certainly not the case for our fiscal deficit.",
#       "Our fiscal prospects are, in my judgment, a significant obstacle to long-term stability because the budget deficit is not readily subject to correction by market forces that stabilize other imbalances."
#     ],
#     "text2_evidence_sentences": [
#       "Despite the relatively favorable performance of the global economy, we face a range of daunting longer-term economic policy challenges.",
#       "For the United States, these challenges are less acute than for many of the major economies, but they are still formidable in their scale and complexity."
#     ],
#     "text1_keywords": ["overly worrisome", "significant obstacle"],
#     "text2_keywords": ["favorable performance", "less acute"]
#   },
#   {
#     "dimension_title": "Complexity to Simplicity",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 11,
#     "text1_evidence_sentences": [
#       "Globalization has altered the economic frameworks of both advanced and developing nations in ways that are difficult to fully comprehend.",
#       "All policymakers are struggling to understand global and technological changes that appear to have profoundly altered world economic developments."
#     ],
#     "text2_evidence_sentences": [
#       "Let me begin by saying that I agree with the thrust of John's remarks.",
#       "He is right that globalization has not fundamentally changed the way central banks should do business."
#     ],
#     "text1_keywords": ["difficult to fully comprehend", "struggling to understand"],
#     "text2_keywords": ["agree", "not fundamentally changed"]
#   },
#   {
#     "dimension_title": "Questioning to Affirmation",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 11,
#     "text1_evidence_sentences": [
#       "Has something fundamental happened to the U.S. economy that enables us to disregard all the timetested criteria for assessing when economic imbalances become worrisome?",
#       "That view holds that the postwar paradigm is still largely in place, and key financial ratios, rather than suggesting an evolving economic structure, reflect extreme values that have materialized within an unchanged structure and must eventually adjust, perhaps abruptly."
#     ],
#     "text2_evidence_sentences": [
#       "By now I believe it has become clear that the initial assessment that the United States had decoupled from the rest of the world was incorrect, and that, in fact, the global economy remains closely connected by both trade and financial linkages.",
#       "The United States thus faces economic \"realities\" similar to those of the advanced and emerging market economies."
#     ],
#     "text1_keywords": ["Has something fundamental happened", "must eventually adjust"],
#     "text2_keywords": ["incorrect", "similar"]
#   }
# ]
# ```
# Tokens used: 37667
# Cost of the request: $0.000075
# Response: ```json
# [
#   {
#     "dimension_title": "Optimism to Concern",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 12,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "You are meeting at a time of greater confidence about the near-term world economic outlook and the stability of the financial system.",
#       "Much of this confidence may prove warranted and durable, but the extent to which it endures will depend in part on the degree to which those running the major financial institutions in the United States use the opportunity presented by this period of relatively high profitability to strengthen their capacity to withstand a less favorable overall macroeconomic and financial environment."
#     ],
#     "text2_evidence_sentences": [
#       "However, although the U.S. economy clearly has slowed, aggressive actions by the Federal Reserve and other central banks as well as fiscal stimulus have helped us weather the storm better than we would have otherwise.",
#       "However, financial markets can do their job well only when they solve information problems that would otherwise impede the efficient allocation of credit to worthy borrowers."
#     ],
#     "text1_keywords": ["greater confidence", "confidence may prove warranted"],
#     "text2_keywords": ["economy clearly has slowed", "information problems"]
#   },
#   {
#     "dimension_title": "Resilience to Vulnerability",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 12,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "A number of fundamental changes in the U.S. financial system over DATE appear to have rendered it able to withstand the stress of a broader array of shocks than was the case in the past.",
#       "The U.S. economy appears to have become more resilient to financial shocks."
#     ],
#     "text2_evidence_sentences": [
#       "As this recent experience suggests, financial liberalization and innovation bring many benefits but can also create information and incentive problems that lead to mistakes.",
#       "When mistakes of this nature become evident, financial markets can seize up, with potentially significant adverse consequences for the economy."
#     ],
#     "text1_keywords": ["able to withstand", "more resilient"],
#     "text2_keywords": ["lead to mistakes", "adverse consequences"]
#   },
#   {
#     "dimension_title": "Strength to Weakness",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_score_text1": 12,
#     "confidence_label_text2": "High",
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "The U.S. financial system is currently enjoying a period of considerable strength.",
#       "Overall, the fundamentals of the U.S. economy look quite strong."
#     ],
#     "text2_evidence_sentences": [
#       "While that market had serious weaknesses that eventually imposed large costs on many borrowers and their communities, it also brought considerable benefits to many others who were able to take advantage of responsible products never before available.",
#       "The subprime crisis exposed problems with the securitization of mortgages."
#     ],
#     "text1_keywords": ["considerable strength", "look quite strong"],
#     "text2_keywords": ["serious weaknesses", "exposed problems"]
#   },
#   {
#     "dimension_title": "Stability to Turmoil",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_score_text1": 12,
#     "confidence_label_text2": "High",
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "The balance between innovation and resilience that has characterized the U.S. financial system in DATE has played an important role in the improved performance of the U.S. economy.",
#       "This seems due, in part, to important fundamental improvements in policy credibility and economic performance."
#     ],
#     "text2_evidence_sentences": [
#       "As you well know, financial markets in the United States and Europe have been under considerable strain for DATE now.",
#       "Speaking as a central banker soon to return to the relatively tranquil ivory tower of Columbia University, I don't think it is far off the mark to characterize the turmoil of DATE as one of the worst financial shocks that the United States has confronted since the Great Depression."
#     ],
#     "text1_keywords": ["innovation and resilience", "economic performance"],
#     "text2_keywords": ["considerable strain", "financial turmoil"]
#   },
#   {
#     "dimension_title": "Progress to Setbacks",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_score_text1": 12,
#     "confidence_label_text2": "High",
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "In both of these areas, market practice has made significant progress over DATE, and further improvements are underway.",
#       "The overall strategy outlined in the public letter signed by the NUM major market participants on DATE, offers the prospect of a more automated confirmation and settlement process, with significantly less operational risk than has existed in these markets since their inception."
#     ],
#     "text2_evidence_sentences": [
#       "When these problems came to light, investors - including leveraged financial institutions - took large losses as the values of mortgage-related assets were marked down in anticipation of higher defaults on the underlying collateral.",
#       "The market for newly issued subprime and altA mortgage-backed securities virtually closed, and the availability of jumbo mortgages dried up."
#     ],
#     "text1_keywords": ["significant progress", "further improvements"],
#     "text2_keywords": ["large losses", "virtually closed"]
#   }
# ]
# ```
# Tokens used: 39075
# Cost of the request: $0.000078
# Response: ```json
# [
#   {
#     "dimension_title": "Concern to Reassurance",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 8,
#     "text1_evidence_sentences": [
#       "Clearly, the evolution of financial institutions and markets has not removed the underlying risks and uncertainties associated with financial transactions, and, in fact may create new forms of risk that may not be clearly understood.",
#       "Financial institutions and other market participants must still make decisions and take actions with incomplete knowledge about the condition of their counterparties."
#     ],
#     "text2_evidence_sentences": [
#       "I am optimistic about the current forward momentum in the United States to develop and implement a final rule for Basel II.",
#       "Implementation of Basel II in the United States is necessary in order to ensure the safe and sound operation of our banking industry and the stability of our financial system."
#     ],
#     "text1_keywords": ["risks and uncertainties", "not be clearly understood"],
#     "text2_keywords": ["optimistic", "safe and sound operation"]
#   },
#   {
#     "dimension_title": "Complexity to Fundamentals",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 8,
#     "text1_evidence_sentences": [
#       "Indeed, the Federal Reserve's main reason for pursuing the advanced approaches of Basel II is the growing inadequacy of current Basel I regulatory capital rules for the large, internationally active banks that are offering ever more complex and sophisticated products and services.",
#       "Since adoption of the MRA, banks' trading activities have become more sophisticated and have given rise to a wider range of risks that are not easily captured in their existing value-at-risk (VaR) models."
#     ],
#     "text2_evidence_sentences": [
#       "The focus of my remarks DATE - the importance of fundamentals in risk management - should still resonate with all of you, whether you are part of a large global bank or a smaller community bank.",
#       "Getting the fundamentals right - and being ever vigilant about their consistent application and execution - forms the basis of any sound risk management system."
#     ],
#     "text1_keywords": ["complex and sophisticated", "trading activities have become more sophisticated"],
#     "text2_keywords": ["importance of fundamentals", "fundamentals right"]
#   },
#   {
#     "dimension_title": "Flexibility to Rigor",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_score_text1": 10,
#     "confidence_label_text2": "Medium",
#     "confidence_score_text2": 8,
#     "text1_evidence_sentences": [
#       "But while the new framework would, in our view, provide useful incentives for institutions to accelerate the improvement of risk management, we believe that in most areas of risk management institutions would continue to have the choice among which specific methods they employ.",
#       "Flexibility has been built into Basel II so that improved techniques for doing such things as measuring potential loss or forecasting exposures can be used within the framework."
#     ],
#     "text2_evidence_sentences": [
#       "Because of its central role in the business of banking, liquidity risk requires rigorous and effective management.",
#       "The bank's ICAAP should ensure that the bank is holding enough overall capital to support its entire risk profile, and it should provide a cushion against the potential impact of periods of financial or economic stress."
#     ],
#     "text1_keywords": ["choice among which specific methods", "flexibility has been built into"],
#     "text2_keywords": ["requires rigorous", "ensure"]
#   },
#   {
#     "dimension_title": "Independence to Interconnectedness",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 8,
#     "text1_evidence_sentences": [
#       "The compliance function should be independent of management whose activities it reviews and monitors.",
#       "An enterprise-wide compliance-risk management program should be dynamic and proactive, meaning it constantly assesses evolving risks when new business lines or activities are added or when existing services or processes are altered."
#     ],
#     "text2_evidence_sentences": [
#       "Additionally, we are all witnessing the extent to which banking and financial markets are interconnected.",
#       "The current environment certainly presents some fundamental challenges for banking institutions of all types and sizes."
#     ],
#     "text1_keywords": ["independent", "enterprise-wide"],
#     "text2_keywords": ["interconnected", "challenges"]
#   }
# ]
# ```
# Tokens used: 40958
# Cost of the request: $0.000082
# Response: ```json
# [
#   {
#     "dimension_title": "Describing Actions to Justifying Actions",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "On DATE TIME, shortly after the attacks, the Federal Reserve issued a press release stating that \"the discount window is available to meet liquidity needs,\" thus reassuring financial markets that the Federal Reserve System was functioning normally.",
#       "The open market desk accommodated all propositions for funding through repurchase agreements down to the target federal funds rate, operating exclusively through TIME transactions for DATE."
#     ],
#     "text2_evidence_sentences": [
#       "One view holds that intervening to prevent the failure of a financial firm is counterproductive, because it leads to erosion of market discipline and creates moral hazard.",
#       "However, in my view, the failure of a major financial institution at a time when financial markets are already quite fragile poses too great a threat to financial and economic stability to be ignored."
#     ],
#     "text1_keywords": ["Federal Reserve issued a press release", "open market desk accommodated"],
#     "text2_keywords": ["intervening to prevent the failure", "poses too great a threat"]
#   },
#   {
#     "dimension_title": "Focus on Operational Details to Focus on Broader Economic Impact",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "The Federal Reserve working with the National Communications System (NCS) also assisted market participants in restoring their telecommunications services.",
#       "The Federal Reserve is working with FBIIC agencies through outreach to expand NCS services to clearing and settlement organizations processing securities."
#     ],
#     "text2_evidence_sentences": [
#       "The Texas economy is strong and diversified, accounting for more than a trillion dollars of output DATE.",
#       "However, our nation, and Texas too, is being tested by economic and financial challenges."
#     ],
#     "text1_keywords": ["telecommunications services", "clearing and settlement organizations"],
#     "text2_keywords": ["Texas economy", "economic and financial challenges"]
#   },
#   {
#     "dimension_title": "Emphasis on Immediate Response to Emphasis on Long-Term Solutions",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "On DATE TIME, shortly after the attacks, the Federal Reserve issued a press release stating that \"the discount window is available to meet liquidity needs,\" thus reassuring financial markets that the Federal Reserve System was functioning normally.",
#       "Borrowing by depository institutions surged to a record $NUM billion by DATE."
#     ],
#     "text2_evidence_sentences": [
#       "Going forward, reforming the system to enhance stability and to address the problem of \"too big to fail\" should be a top priority for lawmakers and regulators.",
#       "In particular, recent events have revealed a serious weakness of our system: the absence of well-defined procedures and authorities for dealing with the potential failure of a systemically important nonbank financial institution."
#     ],
#     "text1_keywords": ["discount window is available", "surged"],
#     "text2_keywords": ["reforming the system", "well-defined procedures"]
#   },
#   {
#     "dimension_title": "Focus on Domestic Actions to Focus on International Coordination",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "Operational disruptions caused uncertainties about payment flows, making it difficult for the reserve market to channel funds to where they were needed most.",
#       "Depository institutions that held more reserve balances than they preferred had difficulty placing and delivering the excess in the market; on the other hand, depository institutions awaiting funds had to scramble to cover overdraft positions."
#     ],
#     "text2_evidence_sentences": [
#       "Half of that reduction came as part of an unprecedented coordinated interest rate cut by six major central banks on DATE NUM.",
#       "In our globalized financial markets, the provision of dollar liquidity has international as well as domestic aspects."
#     ],
#     "text1_keywords": ["payment flows", "reserve balances"],
#     "text2_keywords": ["coordinated interest rate cut", "globalized financial markets"]
#   }
# ]
# ```
# Tokens used: 32398
# Cost of the request: $0.000065
# Response: ```json
# [
#   {
#     "dimension_title": "Emphasis on Cost-Benefit Analysis to Prioritizing Stability",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 16,
#     "confidence_score_text2": 16,
#     "text1_evidence_sentences": [
#       "Today I will discuss bank regulation and supervision from a cost-benefit perspective, focusing on how the Federal Reserve and our fellow bank regulators take benefits and costs into account when we develop rules and supervisory policies.",
#       "My central theme has been that good regulatory and supervisory policies should implement congressional intent in ways that maximize social benefits and minimize social costs."
#     ],
#     "text2_evidence_sentences": [
#       "Notably, to promote financial stability and to address the extremely serious problem posed by firms perceived as \"too big to fail,\" legislative action is needed to create new mechanisms for oversight of the financial system as a whole; to ensure that all systemically important financial firms are subject to effective consolidated supervision; and to establish procedures for winding down a failing, systemically critical institution without seriously damaging the financial system and the economy.",
#       "The world is suffering through the worst financial crisis since DATE, a crisis that has precipitated a sharp downturn in the global economy."
#     ],
#     "text1_keywords": ["cost-benefit perspective", "maximize social benefits and minimize social costs"],
#     "text2_keywords": ["financial stability", "financial crisis"]
#   },
#   {
#     "dimension_title": "Focus on Individual Institutions to Systemic Risk",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 16,
#     "confidence_score_text2": 16,
#     "text1_evidence_sentences": [
#       "Capital regulation is the cornerstone of bank regulators' efforts to maintain a safe and sound banking system, a critical element of overall financial stability.",
#       "Clearly, banks strengthen their local communities by providing a range of services and facilitating the flow of credit necessary to support economic development."
#     ],
#     "text2_evidence_sentences": [
#       "Thus, any effort to address systemic risks will require a more systemwide, or macroprudential, approach to the supervision of systemically critical firms.",
#       "The Federal Reserve supports the creation of a systemic oversight council, made up of the principal financial regulators."
#     ],
#     "text1_keywords": ["safe and sound banking system", "strengthen their local communities"],
#     "text2_keywords": ["systemic risks", "systemic oversight council"]
#   },
#   {
#     "dimension_title": "Emphasis on Agency Discretion to Legislative Action",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 16,
#     "confidence_score_text2": 16,
#     "text1_evidence_sentences": [
#       "Whatever the motivation, once the Congress decides that a particular issue must be addressed, it typically (though not always) gives the federal banking agencies significant discretion to devise the regulations and supervisory policies that implement the statute.",
#       "The Congress has given the banking agencies substantial discretion to determine the methods by which they assign CRA ratings."
#     ],
#     "text2_evidence_sentences": [
#       "Although regulators can do a great deal on their own to improve financial regulation and oversight, the Congress also must act.",
#       "Strengthening consolidated supervision, setting up a mechanism (such as a systemic oversight council) to identify and monitor risks to financial stability, and creating a framework that allows for the safe unwinding of failing, systemically critical firms are among the essential ingredients of a new system that will reduce the probability of future crises and greatly mitigate the severity of any that occur."
#     ],
#     "text1_keywords": ["significant discretion", "substantial discretion"],
#     "text2_keywords": ["Congress also must act", "legislative action"]
#   },
#   {
#     "dimension_title": "Minimizing Regulatory Burden to Strengthening Regulations",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 16,
#     "confidence_score_text2": 16,
#     "text1_evidence_sentences": [
#       "Minimizing the regulatory burden on banks is very important.",
#       "Accordingly, in developing regulatory and supervisory policies, the Federal Reserve and the other banking agencies will continue to pay close attention to the implications of those policies for regulatory burden, competitiveness, and efficiency in banking."
#     ],
#     "text2_evidence_sentences": [
#       "The Federal Reserve has played a key part in the international effort, working through organizations such as the Basel Committee on Bank Supervision and the Financial Stability Board.",
#       "Internationally, the Financial Stability Board has called for significantly stronger capital standards, and the Group of Twenty has committed to develop rules to improve both the quantity and quality of bank capital."
#     ],
#     "text1_keywords": ["regulatory burden", "minimizing"],
#     "text2_keywords": ["stronger capital standards", "improve both the quantity and quality"]
#   },
#   {
#     "dimension_title": "Focus on Banks to Broader Financial Institutions",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 16,
#     "confidence_score_text2": 16,
#     "text1_evidence_sentences": [
#       "Today I will discuss bank regulation and supervision from a cost-benefit perspective, focusing on how the Federal Reserve and our fellow bank regulators take benefits and costs into account when we develop rules and supervisory policies.",
#       "In the rest of my remarks, I will briefly illustrate how the Federal Reserve, along with the other federal banking agencies, applies these principles in three major areas of bank regulation and supervision: the Bank Secrecy Act, bank capital standards, and the Community Reinvestment Act."
#     ],
#     "text2_evidence_sentences": [
#       "The recent financial crisis clearly demonstrated that risks to the financial system can arise not only from banks, but also from other financial firms - such as investment banks or insurance companies - that traditionally have not been subject to the type of regulation and consolidated supervision applied to bank holding companies.",
#       "To close this gap, the Congress should ensure that all systemically important financial institutions are subject to a robust regime for consolidated prudential supervision."
#     ],
#     "text1_keywords": ["bank regulation", "banking agencies"],
#     "text2_keywords": ["other financial firms", "systemically important financial institutions"]
#   }
# ]
# ```
# Tokens used: 42495
# Cost of the request: $0.000085
# Response: ```json
# [
#   {
#     "dimension_title": "Optimism to Concern",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 16,
#     "text1_evidence_sentences": [
#       "In general, the story has been positive for communities and lenders alike.",
#       "DATE, data show record high homeownership rates among low-income and minority borrowers, yet the reports of lending abuses and increased foreclosure rates loom as dark clouds on an otherwise bright horizon."
#     ],
#     "text2_evidence_sentences": [
#       "The challenges facing the housing market at the moment are significant.",
#       "Increasing numbers of homeowners and communities are experiencing problems."
#     ],
#     "text1_keywords": ["positive", "bright horizon"],
#     "text2_keywords": ["challenges", "problems"]
#   },
#   {
#     "dimension_title": "Focus on Access to Credit to Focus on Loan Modification",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 16,
#     "text1_evidence_sentences": [
#       "These laws, the Home Mortgage Disclosure Act (HMDA) and the Community Reinvestment Act (CRA) have increased access to homeownership by making the mortgage market more transparent.",
#       "At the same time that regulatory policy encouraged lenders to serve previously underserved individuals, technological advances in the loan-underwriting process allowed lenders to price for risk more efficiently, expanding access to mortgage credit."
#     ],
#     "text2_evidence_sentences": [
#       "One issue is the possible legal exposure of servicers of mortgages who enter into loan modifications or workout plans.",
#       "Given the substantial number of resets expected from now through DATE, it is in the interest of the industry to go further than it has historically to join together and explore collaborative, creative efforts to develop prudent loan modification programs and other assistance to help large groups of borrowers systematically."
#     ],
#     "text1_keywords": ["increased access", "expanding access"],
#     "text2_keywords": ["loan modifications", "loan modification programs"]
#   },
#   {
#     "dimension_title": "Emphasis on Market Efficiency to Emphasis on Consumer Protection",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 16,
#     "text1_evidence_sentences": [
#       "Federal policy, when properly implemented, can smooth the path to ownership by ensuring that markets operate efficiently.",
#       "The recent amendments of Regulation C, HMDA's implementing regulation, build on the theme that transparency breeds efficiency in markets."
#     ],
#     "text2_evidence_sentences": [
#       "Accordingly, we continue to coordinate with other federal and state agencies, and consult with consumer advocates, lenders, investors, and others.",
#       "Finally, the Board continues to work toward more effective consumer protection rules."
#     ],
#     "text1_keywords": ["markets operate efficiently", "transparency breeds efficiency"],
#     "text2_keywords": ["consumer protection", "consumer advocates"]
#   },
#   {
#     "dimension_title": "Focus on Homeownership to Focus on Sustainable Homeownership",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 16,
#     "text1_evidence_sentences": [
#       "Homeownership Owning a home is one of the most tried-and-true paths to wealth accumulation in our economy.",
#       "Because of these benefits, federal policy in DATE has focused on increasing the homeownership rate among segments of society, such as minorities and low-income individuals, where homeownership had previously been low."
#     ],
#     "text2_evidence_sentences": [
#       "If the benefits of homeownership are to be realized, we believe that homeownership must be sustainable and that access to responsible lending be available for consumers.",
#       "Promoting access to credit and sustainable homeownership are important objectives, and the Board believes that responsible subprime mortgage lending can help advance both goals."
#     ],
#     "text1_keywords": ["homeownership", "increasing the homeownership rate"],
#     "text2_keywords": ["sustainable homeownership", "sustainable"]
#   },
#   {
#     "dimension_title": "Emphasis on Lender Responsibility to Emphasis on Shared Responsibility",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 16,
#     "text1_evidence_sentences": [
#       "The data help identify potential fair lending issues in the institutions regulated by the Federal Reserve and other supervisory agencies.",
#       "It is the role of the CEO and senior management to ensure that procedures and controls throughout the organization support those policies."
#     ],
#     "text2_evidence_sentences": [
#       "We believe that investors and servicers generally want to work with borrowers to avoid foreclosure.",
#       "Loan modification programs should be a bottom-up approach designed to balance the needs of all parties, and we are encouraged by the progress being made by the industry in advancing such programs."
#     ],
#     "text1_keywords": ["institutions regulated", "CEO and senior management"],
#     "text2_keywords": ["investors and servicers", "needs of all parties"]
#   }
# ]
# ```
# Tokens used: 36484
# Cost of the request: $0.000073
# Response: ```json
# [
#   {
#     "dimension_title": "Emphasis on Past Actions to Focus on Future Challenges",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 6,
#     "confidence_score_text2": 6,
#     "text1_evidence_sentences": [
#       "The Federal Reserve's experiences over DATE make it clear that such uncertainty is not just a pervasive feature of the monetary policy landscape; it is the defining characteristic of that landscape.",
#       "Yet, during DATE, policymakers managed to defuse dangerous inflationary forces and to deal with the consequences of a stock market crash, a large asset price bubble, and a series of liquidity crises."
#     ],
#     "text2_evidence_sentences": [
#       "On the economic front, the resumption of growth in the nation's output of goods and services is encouraging.",
#       "These are just some of the challenges that we will all face in DATE."
#     ],
#     "text1_keywords": ["experiences", "policymakers managed"],
#     "text2_keywords": ["economic front", "challenges"]
#   },
#   {
#     "dimension_title": "Acknowledging Limitations to Asserting Capabilities",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 6,
#     "confidence_score_text2": 6,
#     "text1_evidence_sentences": [
#       "However, despite extensive efforts to capture and quantify what we perceive as the key macroeconomic relationships, our knowledge about many of the important linkages is far from complete and, in all likelihood, will always remain so.",
#       "As the transcripts of Federal Open Market Committee meetings attest, faced with these abundant challenges, we find the making of monetary policy to be an especially humbling activity."
#     ],
#     "text2_evidence_sentences": [
#       "We are confident that we have the necessary tools to do so.",
#       "Together I am confident that we will meet whatever challenges the future may bring."
#     ],
#     "text1_keywords": ["knowledge", "humbling activity"],
#     "text2_keywords": ["confident", "necessary tools"]
#   },
#   {
#     "dimension_title": "Emphasis on Independence to Emphasis on Transparency",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 6,
#     "confidence_score_text2": 6,
#     "text1_evidence_sentences": [
#       "The Federal Reserve has been fortunate to have worked in a particularly favorable structural and political environment over DATE.",
#       "But we trust that monetary policy has contributed meaningfully to the impressive performance of our economy in DATE."
#     ],
#     "text2_evidence_sentences": [
#       "We also have renewed and strengthened our longstanding commitment to transparency and accountability.",
#       "However, I believe that we should be prepared to do even more, to become even more transparent."
#     ],
#     "text1_keywords": ["political environment", "monetary policy"],
#     "text2_keywords": ["transparency", "accountability"]
#   }
# ]
# ```
# Tokens used: 27285
# Cost of the request: $0.000055
# Response: ```json
# [
#   {
#     "dimension_title": "Optimism to Concern",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 17,
#     "confidence_score_text2": 17,
#     "text1_evidence_sentences": [
#       "Risk measures derived from prices of publicly traded bank securities - stocks, debt securities, and credit default swaps - also signal that market participants are taking an increasingly positive view of the future of banks.",
#       "Indeed, these measures suggest the lowest level of market concern about these companies that we have seen during the DATE in which we have tracked them."
#     ],
#     "text2_evidence_sentences": [
#       "In addition, while the decline in housing prices slowed in DATE, continued adjustments in the housing market suggest that foreclosures and mortgage loan loss severities are likely to remain elevated.",
#       "Moreover, prices for both existing commercial properties and for land, which collateralize commercial and residential development loans, have declined sharply in DATE of DATE, suggesting that banks are vulnerable to significant further deterioration in their CRE loans."
#     ],
#     "text1_keywords": ["increasingly positive view", "lowest level of market concern"],
#     "text2_keywords": ["likely to remain elevated", "vulnerable to significant further deterioration"]
#   },
#   {
#     "dimension_title": "Strength to Fragility",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 17,
#     "confidence_score_text2": 17,
#     "text1_evidence_sentences": [
#       "DATE, with the benefit of hindsight, we can see that the weaknesses I cited then have indeed been mild for the banking system as a whole and that the system remains strong and well positioned to meet customer needs for credit and other financial services.",
#       "The banking industry's relatively benign experience with loan losses DATE may not be surprising given that the recession was mild by most measures."
#     ],
#     "text2_evidence_sentences": [
#       "However, the banking system remains fragile.",
#       "DATE into a substantial recession, loan quality is poor across many asset classes and, as noted earlier, continues to deteriorate as lingering weakness in housing markets affects the performance of residential mortgages and construction loans."
#     ],
#     "text1_keywords": ["system remains strong", "benign experience"],
#     "text2_keywords": ["banking system remains fragile", "loan quality is poor"]
#   },
#   {
#     "dimension_title": "Confidence to Uncertainty",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 17,
#     "confidence_score_text2": 17,
#     "text1_evidence_sentences": [
#       "The results of DATE interagency review of large syndicated loans and internal reports about the level and distribution of their criticized and classified credits lead us to expect still further improvement in the industry's asset quality DATE.",
#       "Many banks indicate that they now either are interest-rate neutral or are positioned to benefit from rising rates."
#     ],
#     "text2_evidence_sentences": [
#       "Almost all of the banks that tightened standards indicated concerns about a weaker or more uncertain economic outlook, and about one-third of banks surveyed cited concerns about deterioration in their own current or future capital positions.",
#       "Higher loan losses are depleting loan loss reserves at many banking organizations, necessitating large new provisions that are producing net losses or low earnings."
#     ],
#     "text1_keywords": ["expect still further improvement", "positioned to benefit"],
#     "text2_keywords": ["weaker or more uncertain economic outlook", "necessitating large new provisions"]
#   },
#   {
#     "dimension_title": "Growth to Contraction",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 17,
#     "confidence_score_text2": 17,
#     "text1_evidence_sentences": [
#       "For DATE, commercial banks reported net profits of more than $NUM billion while maintaining historically high equity and risk-based capital ratios and enjoying brisk asset growth.",
#       "Residential mortgage loans and pass-through securities have increased from NUM percent of assets in DATE to NUM percent in DATE."
#     ],
#     "text2_evidence_sentences": [
#       "According to the Federal Reserve's Flow of Funds accounts, household and nonfinancial business debt contracted in DATE and appears to have decreased again in DATE.",
#       "At depository institutions, loans outstanding fell in DATE."
#     ],
#     "text1_keywords": ["brisk asset growth", "increased"],
#     "text2_keywords": ["debt contracted", "loans outstanding fell"]
#   },
#   {
#     "dimension_title": "Mild Deterioration to Significant Deterioration",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 17,
#     "confidence_score_text2": 17,
#     "text1_evidence_sentences": [
#       "When I last discussed the condition of the banking industry with this committee in DATE, the industry's asset quality had begun to decline, but from a relatively high level, and banks were generally well positioned to deal with the emerging problems.",
#       "Moreover, as early as DATE, both the industry and bank supervisors had begun to address the slippage in credit standards that was one of the causes of the drop in asset quality."
#     ],
#     "text2_evidence_sentences": [
#       "Credit losses at banking organizations continued to rise through DATE of DATE, and banks face risks of sizable additional credit losses given the outlook for production and employment.",
#       "Loan quality deteriorated significantly for both large and small institutions during DATE."
#     ],
#     "text1_keywords": ["begun to decline", "slippage in credit standards"],
#     "text2_keywords": ["credit losses", "deteriorated significantly"]
#   }
# ]
# ```
# Tokens used: 41631
# Cost of the request: $0.000083
# Response: ```json
# [
#   {
#     "dimension_title": "Concern to Urgency",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 11,
#     "text1_evidence_sentences": [
#       "This favorable short-term outlook for the U.S. economy, however, is playing out against a backdrop of growing concern about the prospects for the federal budget.",
#       "Many analysts are becoming increasingly concerned that, without a restoration of the budget enforcement mechanisms and the fundamental political will they signal, the inbuilt political bias in favor of red ink will once again become entrenched."
#     ],
#     "text2_evidence_sentences": [
#       "Thank you for the opportunity to join you DATE, both to attend and to participate in this event on a topic of some urgency.",
#       "The United States is moving into an era in which government finance is taking center stage."
#     ],
#     "text1_keywords": ["growing concern", "increasingly concerned"],
#     "text2_keywords": ["some urgency", "taking center stage"]
#   },
#   {
#     "dimension_title": "Restraint to Action",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_score_text1": 11,
#     "confidence_label_text2": "High",
#     "confidence_score_text2": 11,
#     "text1_evidence_sentences": [
#       "In my judgment, the necessary choices will be especially difficult to implement without the restoration of a set of procedural restraints on the budget-making process.",
#       "Reinstating a structure like the one provided by the Budget Enforcement Act would signal a renewed commitment to fiscal restraint and help restore discipline to the DATE budgeting process."
#     ],
#     "text2_evidence_sentences": [
#       "Or third, the most difficult and probably the least palatable politically: We can act now to implement programs that reduce spending and increase revenues to a more sustainable level.",
#       "We can act now to implement programs that reduce spending and increase revenues to a more sustainable level."
#     ],
#     "text1_keywords": ["fiscal restraint", "procedural restraints"],
#     "text2_keywords": ["We can act now", "implement programs"]
#   },
#   {
#     "dimension_title": "Hope to Inevitability",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 11,
#     "text1_evidence_sentences": [
#       "I trust that the recent deterioration in the budget outlook and the fastapproaching retirement of the baby-boom generation will be met with similar determination and effectiveness.",
#       "History has shown that, when faced with major challenges, elected officials have risen to the occasion."
#     ],
#     "text2_evidence_sentences": [
#       "It seems inevitable that a government turns to its central bank to bridge budget shortfalls, with the result being too-rapid money creation and eventually, not immediately, high inflation.",
#       "Eventually, government budgets that are severely out of balance are inevitably reformed - either by force of the markets or, preferably, by choice."
#     ],
#     "text1_keywords": ["I trust", "risen to the occasion"],
#     "text2_keywords": ["seems inevitable", "inevitably reformed"]
#   },
#   {
#     "dimension_title": "Generality to Specificity",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 11,
#     "text1_evidence_sentences": [
#       "The one certainty is that the resolution of this situation will require difficult choices and that the future performance of the economy will depend on those choices.",
#       "No changes will be easy, as they all will involve lowering claims on resources or raising financial obligations."
#     ],
#     "text2_evidence_sentences": [
#       "It means, for example, controlling budget earmarks, trimming subsidies to numerous economic sectors, and resolving our banking problems and the perception that Wall Street is favored over Main Street, all of which would otherwise foster mistrust and cynicism among the public.",
#       "Without being specific, these requirements suggest an approach in which we are willing to disappoint a host of special interests."
#     ],
#     "text1_keywords": ["difficult choices", "lowering claims on resources"],
#     "text2_keywords": ["controlling budget earmarks", "trimming subsidies"]
#   }
# ]
# ```
# Tokens used: 21827
# Cost of the request: $0.000044

# %% [markdown]
# Random contextual boundary

# %%
random_cb0_df = topol_model.df.filter(pl.col("random_label") == 0).clone()
top_k_docs = get_top_k_representative_docs(random_cb0_cluster_info, random_cb0_df, k=K)
random_cb0_cluster_info = random_cb0_cluster_info.join(top_k_docs, on="cluster", how="left")

# %%
random_cb1_df = topol_model.df.filter(pl.col("random_label") == 1).clone()
top_k_docs = get_top_k_representative_docs(random_cb1_cluster_info, random_cb1_df, k=K)
random_cb1_cluster_info = random_cb1_cluster_info.join(top_k_docs, on="cluster", how="left")

# %%
for cluster_id in tqdm(clusters, desc="Processing random clusters"):
    cb0_row = random_cb0_cluster_info.filter(pl.col("cluster") == cluster_id).to_dicts()[0]
    cb1_row = random_cb1_cluster_info.filter(pl.col("cluster") == cluster_id).to_dicts()[0]

    # Generate the prompt for the LLM
    text1 = from_list_to_string(cb0_row["top_docs"])
    text2 = from_list_to_string(cb1_row["top_docs"])
    prompt = generate_narrative_comparison_prompt(text1, text2)
    response = chat_completion_func(prompt, **text_generation_params)

    # Parse the JSON response safely
    parsed_llm_out = safe_json_load(response)

    # Save to file
    fname = f"{FILES_PREFIX}_random_cluster_{cluster_id}.json"
    fpath = os.path.join(XAI2_PATH, fname)
    with open(fpath, "w", encoding="utf-8") as f:
        json.dump(parsed_llm_out, f, ensure_ascii=False, indent=2)
# Out:
# Processing random clusters:   0%|          | 0/11 [00:00<?, ?it/s]
# Response: ```json
# [
#   {
#     "dimension_title": "Emphasis on Historical Analysis to Forward-Looking Projections",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 3,
#     "confidence_score_text2": 4,
#     "text1_evidence_sentences": [
#       "As a consequence, the Federal Reserve was perceived by some as often accentuating, rather than damping, cycles in prices and activity.",
#       "Importantly, however, the surge in prices that followed the removal of wage and price controls after World War II and again after the Korean War kept monetary policymakers wary of the threat of inflation."
#     ],
#     "text2_evidence_sentences": [
#       "Effective communication not only about inflation but also about the possible path of the policy rate may be particularly important at the zero lower bound, when the scope to influence expectations through changes in the policy rate is obviously limited.",
#       "And, in a historically unusual period, the economic developments motivating central bank actions may be more difficult to interpret and predict than in typical periods, making such communication especially important."
#     ],
#     "text1_keywords": ["cycles in prices and activity", "wage and price controls"],
#     "text2_keywords": ["future path", "interpret and predict"]
#   },
#   {
#     "dimension_title": "Focus on Aggregate Data to Emphasis on Financial Intermediation",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 3,
#     "confidence_score_text2": 4,
#     "text1_evidence_sentences": [
#       "In the absence of a single variable, or at most a few, that can serve as a reliable guide, policymakers have been forced to fall back on an approach that entails the interpretation of the full range of economic and financial data.",
#       "Policy is implemented through nominal and, implicitly, real short-term interest rates."
#     ],
#     "text2_evidence_sentences": [
#       "From the onset of this financial crisis, we were especially alert to the possibility that limits on the availability of credit to financial intermediaries and in the flow of credit between intermediaries and the household and business sectors could exert unusual constraints on spending.",
#       "It is fair to say, however, that the core macroeconomic modeling framework used at the Federal Reserve and other central banks around the world has included, at best, only a limited role for the balance sheets of households and firms, credit provision, and financial intermediation."
#     ],
#     "text1_keywords": ["economic and financial data", "short-term interest rates"],
#     "text2_keywords": ["financial intermediaries", "credit provision"]
#   },
#   {
#     "dimension_title": "Limited Transparency to Increased Transparency",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 3,
#     "confidence_score_text2": 4,
#     "text1_evidence_sentences": [
#       "We have moved toward greater transparency at a \"measured pace\" in part because we were concerned about potential feedback on the policy process and about being misinterpreted - as indeed we were from time to time.",
#       "I do not intend this brief and necessarily incomplete review of events to illustrate how far we have come or to despair of how far we have to go."
#     ],
#     "text2_evidence_sentences": [
#       "The Federal Reserve has acted to enhance that understanding in the current environment by lengthening the horizon of the economic projections of Federal Open Market Committee (FOMC) participants and by providing additional information about their objectives for inflation.",
#       "Our efforts to inform the public better about our expectations for inflation illustrate another strand of research that has informed recent policy actions."
#     ],
#     "text1_keywords": ["greater transparency", "misinterpreted"],
#     "text2_keywords": ["additional information", "inform the public"]
#   },
#   {
#     "dimension_title": "Focus on Price Stability to Balancing Price Stability with Financial Stability",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 3,
#     "confidence_score_text2": 4,
#     "text1_evidence_sentences": [
#       "Indeed, the insights from the work of Friedman and Schwartz DATE gained greater prominence in the realm of practical policy.",
#       "Inflation again became widely viewed as being detrimental to financial stability and macroeconomic performance."
#     ],
#     "text2_evidence_sentences": [
#       "The public's understanding of the central bank's commitment to price stability helps to anchor inflation expectations, thereby contributing to stability in both prices and economic activity.",
#       "The stability of long-run inflation expectations during the current crisis has facilitated the policy response and should contribute to the recovery."
#     ],
#     "text1_keywords": ["monetary roots of inflation", "financial stability"],
#     "text2_keywords": ["price stability", "economic activity"]
#   }
# ]
# ```
# Tokens used: 41230
# Cost of the request: $0.000082
# Response: ```json
# [
#   {
#     "dimension_title": "Concern to Cautious Optimism",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "Clearly, the U.S. economy is going through a very difficult period.",
#       "However, in light of the recent turbulence in financial markets, the uncertainty attending this forecast is quite high and the risks remain to the downside."
#     ],
#     "text2_evidence_sentences": [
#       "We continue to expect economic activity to bottom out, then to turn up DATE.",
#       "Key elements of this forecast are our assessments that the housing market is beginning to stabilize and that the sharp inventory liquidation that has been in progress will slow over DATE."
#     ],
#     "text1_keywords": ["very difficult period", "uncertainty attending this forecast"],
#     "text2_keywords": ["bottom out", "beginning to stabilize"]
#   },
#   {
#     "dimension_title": "Emphasis on Financial Market Strains to Focus on Gradual Repair",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "Although our recent actions appear to have helped stabilize the situation somewhat, financial markets remain under considerable stress.",
#       "The effects of the financial strains on credit cost and availability have become increasingly evident, with some portions of the system that had previously escaped the worst of the turmoil - such as the markets for municipal bonds and student loans - having been affected."
#     ],
#     "text2_evidence_sentences": [
#       "Conditions in a number of financial markets have improved in DATE, reflecting in part the somewhat more encouraging economic data.",
#       "Key elements of this forecast are our assessments that the housing market is beginning to stabilize and that the sharp inventory liquidation that has been in progress will slow over DATE."
#     ],
#     "text1_keywords": ["considerable stress", "financial strains"],
#     "text2_keywords": ["improved", "beginning to stabilize"]
#   },
#   {
#     "dimension_title": "Pessimism about Housing Market to Signs of Stabilization",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "Notably, in the housing market, sales of both new and existing homes have generally continued weak, partly as a result of the reduced availability of mortgage credit, and home prices have continued to fall.",
#       "Residential construction is likely to contract somewhat further in DATE as builders try to reduce their high inventories of unsold new homes."
#     ],
#     "text2_evidence_sentences": [
#       "The housing market, which has been in decline for DATE, has also shown some signs of bottoming.",
#       "Sales of existing homes have been fairly stable since DATE, and sales of new homes have firmed a bit recently, though both remain at depressed levels."
#     ],
#     "text1_keywords": ["continued weak", "continued to fall"],
#     "text2_keywords": ["signs of bottoming", "fairly stable"]
#   },
#   {
#     "dimension_title": "Emphasis on Economic Weakness to Tentative Signs of Improvement",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "Overall, the near-term economic outlook has weakened relative to the projections released by the Federal Open Market Committee (FOMC) at the end of DATE.",
#       "It now appears likely that real gross domestic product (GDP) will not grow much, if at all, over DATE and could even contract slightly."
#     ],
#     "text2_evidence_sentences": [
#       "However, the recent data also suggest that the pace of contraction may be slowing, and they include some tentative signs that final demand, especially demand by households, may be stabilizing.",
#       "A few indicators suggest, again quite tentatively, that the decline in foreign economic activity may also be moderating."
#     ],
#     "text1_keywords": ["weakened", "contract slightly"],
#     "text2_keywords": ["slowing", "tentative signs"]
#   }
# ]
# ```
# Tokens used: 30825
# Cost of the request: $0.000062
# Response: ```json
# [
#   {
#     "dimension_title": "Concern to Reassurance",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 16,
#     "confidence_score_text2": 11,
#     "text1_evidence_sentences": [
#       "These large global imbalances, our current account deficit and the surpluses that are the counterpart to our deficit, will have to come down over time.",
#       "Confidence that the U.S. political system will act to generate a sustainable fiscal trajectory is important to raising the probability that this process of adjustment unfolds with less risk."
#     ],
#     "text2_evidence_sentences": [
#       "The resolution of our current account deficit and household debt burdens does not strike me as overly worrisome, but that is certainly not the case for our fiscal deficit.",
#       "Our fiscal prospects are, in my judgment, a significant obstacle to long-term stability because the budget deficit is not readily subject to correction by market forces that stabilize other imbalances."
#     ],
#     "text1_keywords": ["less risk", "imbalances"],
#     "text2_keywords": ["not strike me as overly worrisome", "significant obstacle"]
#   },
#   {
#     "dimension_title": "Uncertainty to Understanding",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 16,
#     "confidence_score_text2": 11,
#     "text1_evidence_sentences": [
#       "This has been a distinguishing feature of the present expansion, but it is not something we fully understand, and we cannot be confident in judgments about how durable it will prove to be.",
#       "To a significant extent, these financial developments reflect a high degree of confidence in future macroeconomic and financial stability, reinforced by the improvements in inflation performance, growth outcomes and financial resilience of DATE."
#     ],
#     "text2_evidence_sentences": [
#       "We have, I believe, a reasonably good understanding of why Americans have been able to reach farther into global markets, incur significant increases in debt, and yet fail to produce the disruptions so often observed as a consequence.",
#       "However, a widely held alternative view of DATE cannot readily be dismissed."
#     ],
#     "text1_keywords": ["not something we fully understand", "cannot be confident"],
#     "text2_keywords": ["reasonably good understanding", "cannot readily be dismissed"]
#   },
#   {
#     "dimension_title": "Emphasis on Policy to Emphasis on Market Forces",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 16,
#     "confidence_score_text2": 11,
#     "text1_evidence_sentences": [
#       "Given this broad context, I want to touch briefly on some of the policy issues that are likely to be important to the prospects for economic performance, here and around the world.",
#       "Economic policy, in general, needs to be more forward looking in providing a longer-term framework for stability."
#     ],
#     "text2_evidence_sentences": [
#       "But should such initiatives fall short, the marked increase in the economic flexibility of the American economy that has developed in DATE suggests that market forces should over time restore, without crises, a sustainable U.S. balance of payments.",
#       "In a world economy that is sufficiently flexible, as debt projections rise, product and equity prices, interest rates, and exchange rates presumably would change to reestablish global balance."
#     ],
#     "text1_keywords": ["policy issues", "economic policy"],
#     "text2_keywords": ["market forces", "economic flexibility"]
#   },
#   {
#     "dimension_title": "Vulnerability to Resilience",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 16,
#     "confidence_score_text2": 11,
#     "text1_evidence_sentences": [
#       "In emerging markets, better monetary policy has been accompanied by more disciplined and conservative fiscal policy and a range of other policies that have reduced, though not eliminated, vulnerability to changes in confidence, capital flows and exchange rate movements.",
#       "If they are large enough, they have the potential to alter or distort current decisions about investment and consumption in a way that could be detrimental to our longer-run growth prospects."
#     ],
#     "text2_evidence_sentences": [
#       "Flexibility, as history persuasively shows, enables an economic system to better absorb and rebound from shocks.",
#       "The experience over DATE of trade and finance among the individual states that make up the United States comes close to that paradigm of flexibility, even though exchange rates among the states have been fixed."
#     ],
#     "text1_keywords": ["vulnerability", "detrimental"],
#     "text2_keywords": ["flexibility", "rebound from shocks"]
#   }
# ]
# ```
# Tokens used: 38728
# Cost of the request: $0.000077
# Response: ```json
# [
#   {
#     "dimension_title": "Concern to Reassurance",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "But we certainly should not read this experience as meaning that we are free of systemic risk - the risk of financial-sector problems spilling into the real sector or aggravating already difficult economic circumstances.",
#       "Indeed, I see several reasons for carefully considering the potential for such problems to emerge."
#     ],
#     "text2_evidence_sentences": [
#       "The U.S. financial system is currently enjoying a period of considerable strength.",
#       "The system has been remarkably resilient in the face of a range of recent challenges."
#     ],
#     "text1_keywords": ["systemic risk", "potential for such problems to emerge"],
#     "text2_keywords": ["considerable strength", "remarkably resilient"]
#   },
#   {
#     "dimension_title": "Emphasis on Market Fragility to Market Strength",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "We could face situations in which asset price movements are exacerbated by the actions of market participants, including dynamic hedging strategies or forced liquidations of assets to meet margin calls, and those asset price movements could feed back onto the economy.",
#       "Finally, although risks are better dispersed, the credit-risk transfer markets are dependent on a small set of key intermediaries."
#     ],
#     "text2_evidence_sentences": [
#       "Financial institutions are strong.",
#       "Financial innovation has spurred advances in risk management."
#     ],
#     "text1_keywords": ["asset price movements", "dependent on a small set of key intermediaries"],
#     "text2_keywords": ["financial institutions are strong", "advances in risk management"]
#   },
#   {
#     "dimension_title": "Focus on Potential Problems to Focus on Improvements",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "Greater uncertainty about where risks are lodged is the flip side of better dispersion of those risks, especially to less regulated sectors, and of more resilience of the whole system.",
#       "Although the critical roles that these core institutions play in global markets require us to focus on them, we need to address the possibility that this approach could increase moral hazard by reinforcing perceptions that these institutions are too big to fail."
#     ],
#     "text2_evidence_sentences": [
#       "Market practices surrounding key products such as OTC derivatives have been strengthened.",
#       "And the industry's payments infrastructure has been improved by additional safeguards and new clearing and settlement arrangements."
#     ],
#     "text1_keywords": ["greater uncertainty", "increase moral hazard"],
#     "text2_keywords": ["strengthened", "improved"]
#   },
#   {
#     "dimension_title": "Emphasis on Limits to Action to Emphasis on Capacity",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "We need to accept that accidents will happen - that asset prices will fluctuate, often over wide ranges, and those fluctuations will be driven in part by trading strategies, by the cycles of greed and fear that have always been with us, and by the ebb and flow of competition for market share.",
#       "Market-intermediated finance also requires us to live with less control and less knowledge than we had when banks were dominant."
#     ],
#     "text2_evidence_sentences": [
#       "These experiences led to changes in risk management practices, in supervision, and in our capacity as a central bank to contain systemic risk.",
#       "These responses have reduced the overall vulnerability of the system to the types of shocks we've experienced."
#     ],
#     "text1_keywords": ["accidents will happen", "less control and less knowledge"],
#     "text2_keywords": ["our capacity", "reduced the overall vulnerability"]
#   },
#   {
#     "dimension_title": "Focus on Potential for Contagion to Focus on Contained Impact",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "Moreover, the layers of intermediation between borrower and lender that increasingly characterize the financial system may have created new channels for the transmission of shocks within the financial markets and into the economy.",
#       "In the extreme, price variations and other adverse developments could call into question the viability of these intermediaries, threatening a larger cumulative real effect."
#     ],
#     "text2_evidence_sentences": [
#       "However, thus far the dramatic widening of spreads on the riskier tranches of subprime securitizations has not produced spillovers large enough to threaten stability.",
#       "The recent record is reassuring, but no financial system is without vulnerability."
#     ],
#     "text1_keywords": ["transmission of shocks", "threatening a larger cumulative real effect"],
#     "text2_keywords": ["not produced spillovers large enough to threaten stability", "reassuring"]
#   }
# ]
# ```
# Tokens used: 40922
# Cost of the request: $0.000082
# Response: ```json
# [
#   {
#     "dimension_title": "Emphasis on Quantitative Rigor to Acknowledging Qualitative Factors",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "Under the advanced approaches, in particular, banks will be required to adopt more-formal, quantitative risk-measurement and risk-management procedures and processes.",
#       "In this area, we expect to hold institutions to standards that will be just as high as those pertaining to quantification and data maintenance."
#     ],
#     "text2_evidence_sentences": [
#       "Financial stability, portfolio concentration, regulatory capital, enterprise compliance, and clear consumer disclosures all reflect varying types of risk exposures and risk mitigation.",
#       "When banks determine their business strategies and the inherent risks they create, supervisors expect banks to develop appropriate risk management practices to ensure that mitigating controls are in place to limit risks to the desired levels."
#     ],
#     "text1_keywords": ["quantitative", "data maintenance"],
#     "text2_keywords": ["risk exposures", "risk mitigation"]
#   },
#   {
#     "dimension_title": "Focus on Basel II Framework to Broader Supervisory Concerns",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 15,
#     "confidence_score_text2": 20,
#     "text1_evidence_sentences": [
#       "Today I plan to share with you some views on the Basel II framework, especially its proposed implementation in the United States.",
#       "Critical to Basel II is the effort to improve risk measurement and management, especially at our largest, most complex organizations."
#     ],
#     "text2_evidence_sentences": [
#       "DATE, I want to focus on some current supervisory issues to illustrate how financial stability, portfolio concentration, regulatory capital, enterprise compliance, and clear consumer disclosures all reflect varying types of risk exposures and risk mitigation.",
#       "I would now like to turn to another area of the financial sector that regulators are focused on: compliance-risk management."
#     ],
#     "text1_keywords": ["Basel II framework", "implementation"],
#     "text2_keywords": ["supervisory issues", "compliance-risk management"]
#   },
#   {
#     "dimension_title": "Emphasis on Data Limitations to Focus on Economic Conditions",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 10,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "Analysis of the data used in QIS4 is vitally important, because the ultimate success of Basel II will depend both on the quantity and quality of data that banks have to use as inputs to the framework and on our understanding of the limitations of those data.",
#       "Even though we are still in the midst of our analysis of QIS4 data, we recognize that substantial data limitations may prevent banks from developing viable and robust parameter estimates in the near term."
#     ],
#     "text2_evidence_sentences": [
#       "Investors currently seem optimistic about the economic and financial outlook, with risk spreads relatively narrow and implied volatilities fairly low.",
#       "At this point, investors do not appear to believe that financial institutions are unduly exposed to any particular risk type or to risks in the aggregate."
#     ],
#     "text1_keywords": ["data limitations", "quantity and quality of data"],
#     "text2_keywords": ["economic and financial outlook", "financial institutions"]
#   },
#   {
#     "dimension_title": "Focus on Basel II's Benefits to Acknowledging Implementation Challenges",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 15,
#     "confidence_score_text2": 15,
#     "text1_evidence_sentences": [
#       "Our hope is that the implementation of Basel II will substantially improve institutions' ability to measure and manage their risks.",
#       "Finally, we also anticipate that Basel II will allow for the open development of new risk-management techniques, as they evolve over time."
#     ],
#     "text2_evidence_sentences": [
#       "We recognize that the adoption of differing approaches to Basel II by various countries may create challenges for banking organizations that operate in multiple jurisdictions, but it is good to remember that cross-border banking has always raised specific challenges that supervisors from various countries have worked hard to address.",
#       "We encourage bankers that have questions and concerns about home-host issues to promptly communicate with their regulators in all jurisdictions so that the issues can be addressed."
#     ],
#     "text1_keywords": ["improve institutions' ability", "new risk-management techniques"],
#     "text2_keywords": ["challenges", "home-host issues"]
#   }
# ]
# ```
# Tokens used: 42020
# Cost of the request: $0.000084
# Response: ```json
# [
#   {
#     "dimension_title": "Concern to Reassurance",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "DATE, concerns about capital, asset quality, and credit risk continue to limit the willingness of many intermediaries to extend credit, notwithstanding the access of these firms to central bank liquidity.",
#       "The likely duration of the financial turmoil is difficult to judge, and thus the uncertainty surrounding the economic outlook is unusually large."
#     ],
#     "text2_evidence_sentences": [
#       "We have done so in a responsible way: The credit risk associated with our nontraditional policies is exceptionally low, and, by carefully monitoring our balance sheet and developing tools to drain bank reserves as needed, we will ensure that policy accommodation can be reversed at the appropriate time to avoid risks of future inflation.",
#       "The Treasury stands behind the debt and other securities issued by the GSEs."
#     ],
#     "text1_keywords": ["concerns about capital", "uncertainty surrounding the economic outlook"],
#     "text2_keywords": ["responsible way", "exceptionally low"]
#   },
#   {
#     "dimension_title": "Crisis Response to Policy Assessment",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "The Federal Reserve has responded forcefully to the financial and economic crisis since its emergence in DATE.",
#       "Over the course of the crisis, the Fed has taken a number of extraordinary actions, including the creation of a number of new facilities for auctioning short-term credit, to ensure that financial institutions have adequate access to liquidity."
#     ],
#     "text2_evidence_sentences": [
#       "The Federal Reserve is engaged in continuous assessment of the effectiveness of its creditrelated tools, and we have generally been encouraged by the market responses.",
#       "The Federal Reserve is engaged in an ongoing assessment of the effectiveness of its creditrelated tools."
#     ],
#     "text1_keywords": ["responded forcefully", "extraordinary actions"],
#     "text2_keywords": ["continuous assessment", "been encouraged"]
#   },
#   {
#     "dimension_title": "Emphasis on Liquidity to Emphasis on Credit",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "The first set of tools is closely tied to the central bank's traditional role of providing short-term liquidity to sound financial institutions.",
#       "The provision of short-term credit to financial institutions exposes the Federal Reserve to minimal credit risk, as the loans we make to financial institutions are generally short-term, overcollateralized, and made with recourse to the borrowing firm."
#     ],
#     "text2_evidence_sentences": [
#       "To further ease financial conditions, beyond what can be attained by reducing short-term interest rates, the Federal Reserve has taken additional steps to improve the functioning of credit markets and to increase the supply of credit to households and businesses - a policy strategy that I have called \"credit easing.\"",
#       "To address these issues, the Federal Reserve has developed a second set of policy tools, which involve the provision of liquidity directly to borrowers and investors in key credit markets."
#     ],
#     "text1_keywords": ["providing short-term liquidity", "minimal credit risk"],
#     "text2_keywords": ["improve the functioning of credit markets", "liquidity directly to borrowers"]
#   },
#   {
#     "dimension_title": "Minimizing Risk to Managing Risk",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "These special lending programs have been set up to minimize credit risk to the Federal Reserve.",
#       "The largest program, the commercial paper funding facility, accepts only the most highly rated paper."
#     ],
#     "text2_evidence_sentences": [
#       "But we intend, over time, to sell the assets acquired in those transactions in a way that maximizes the return to taxpayers, and we expect to recover the credit we have extended.",
#       "Moreover, in assessing the financial risks of those transactions, once again one must also consider the very grave risks our nation would have incurred had public policy makers not acted in those instances."
#     ],
#     "text1_keywords": ["minimize credit risk", "most highly rated paper"],
#     "text2_keywords": ["maximizes the return to taxpayers", "financial risks"]
#   },
#   {
#     "dimension_title": "Transparency as Policy to Transparency as Review",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "I firmly believe that central banks should be as transparent as possible, both for reasons of democratic accountability and because many of our policies are likely to be more effective if they are well understood by the markets and the public.",
#       "Likewise, the Federal Reserve is committed to keeping the Congress and the public informed about its lending programs and balance sheet."
#     ],
#     "text2_evidence_sentences": [
#       "For this reason, we at the Fed have begun a thorough review of our disclosure policies and the effectiveness of our communication.",
#       "Second, at my request, Board Vice Chairman Donald Kohn is leading a committee that will review our current publications and disclosure policies relating to the Fed's balance sheet and lending policies."
#     ],
#     "text1_keywords": ["transparent as possible", "keeping the Congress and the public informed"],
#     "text2_keywords": ["thorough review", "review our current publications"]
#   }
# ]
# ```
# Tokens used: 42488
# Cost of the request: $0.000085
# Response: ```json
# [
#   {
#     "dimension_title": "Acknowledging Failures to Proposing Solutions",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "Unfortunately, regulators and supervisors did not identify and remedy many of those weaknesses in a timely way.NUM Accordingly, all financial regulators, including of course the Federal Reserve, must take a hard look at the experience of DATE, correct identified shortcomings, and improve future performance.",
#       "As I noted earlier, the events of DATE revealed serious failures in risk management at regulated financial firms that, in turn, underscored the need for supervisors to identify weaknesses in a more timely way and to more effectively ensure financial institutions remedy the problems."
#     ],
#     "text2_evidence_sentences": [
#       "DATE, I would like to talk about four key elements of such a strategy.",
#       "In my remarks, I will discuss several components of a broad policy agenda to address systemic risk: consolidated supervision, the development of a resolution regime for systemically important nonbank financial institutions; more uniform and robust authority for the prudential supervision of systemically important payment and settlement systems; consumer protection; and the potential benefits of charging a governmental entity with more express responsibility for monitoring and addressing systemic risks in the financial system."
#     ],
#     "text1_keywords": ["did not identify", "serious failures"],
#     "text2_keywords": ["key elements", "policy agenda"]
#   },
#   {
#     "dimension_title": "Reactive Assessment to Proactive Prevention",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "The recent financial crisis clearly demonstrated that risks to the financial system can arise not only from banks, but also from other financial firms - such as investment banks or insurance companies - that traditionally have not been subject to the type of regulation and consolidated supervision applied to bank holding companies.",
#       "The Lehman experience clearly demonstrates that the financial system and the broader economy can be placed at risk by the failure of financial firms that traditionally have not been subject to the type of consolidated supervision applied to bank holding companies."
#     ],
#     "text2_evidence_sentences": [
#       "At the same time that we are addressing such immediate challenges, it is not too soon for policymakers to begin thinking about the reforms to the financial architecture, broadly conceived, that could help prevent a similar crisis from developing in the future.",
#       "We must have a strategy that regulates the financial system as a whole, in a holistic way, not just its individual components."
#     ],
#     "text1_keywords": ["clearly demonstrated", "can arise"],
#     "text2_keywords": ["help prevent", "strategy that regulates"]
#   },
#   {
#     "dimension_title": "Firm-Specific Focus to System-Wide Perspective",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "On the supervisory front, we are taking steps to strengthen oversight and enforcement, particularly at the firmwide level, and we are augmenting our traditional microprudential, or firm-specific, methods of oversight with a more macroprudential, or systemwide, approach that should help us better anticipate and mitigate broader threats to financial stability.",
#       "More generally, supervisors must go beyond their traditional focus on individual firms and markets to try to identify possible channels of financial contagion and other risks to the system as a whole."
#     ],
#     "text2_evidence_sentences": [
#       "We must have a strategy that regulates the financial system as a whole, in a holistic way, not just its individual components.",
#       "Financial stability, however, could be further enhanced by a more explicitly macroprudential approach to financial regulation and supervision in the United States."
#     ],
#     "text1_keywords": ["firm-specific", "individual firms"],
#     "text2_keywords": ["financial system as a whole", "macroprudential approach"]
#   },
#   {
#     "dimension_title": "Fragmented Authority to Consolidated Oversight",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "Under the current system, no single regulator is able to develop a comprehensive understanding of the interdependencies, risks, and risk-management approaches across the full range of arrangements serving the financial markets DATE.",
#       "Currently, the Federal Reserve relies on a patchwork of authorities, largely derived from our role as a banking supervisor, as well as on moral suasion to help ensure that critical payment and settlement systems have the necessary procedures and controls in place to manage their risks."
#     ],
#     "text2_evidence_sentences": [
#       "In particular, strong and effective regulation and supervision of banking institutions, although necessary for reducing systemic risk, are not sufficient by themselves to achieve this aim.",
#       "Thus a first component of an agenda for systemic risk regulation is that each systemically important financial firm be subject to effective consolidated supervision."
#     ],
#     "text1_keywords": ["no single regulator", "patchwork of authorities"],
#     "text2_keywords": ["strong and effective regulation", "consolidated supervision"]
#   },
#   {
#     "dimension_title": "Implicit Support to Explicit Resolution",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "Notably, to promote financial stability and to address the extremely serious problem posed by firms perceived as \"too big to fail,\" legislative action is needed to create new mechanisms for oversight of the financial system as a whole; to ensure that all systemically important financial firms are subject to effective consolidated supervision; and to establish procedures for winding down a failing, systemically critical institution without seriously damaging the financial system and the economy.",
#       "To further ameliorate the too-big-to-fail problem, the Congress should create a new set of authorities to facilitate the orderly resolution of failing, systemically important financial firms."
#     ],
#     "text2_evidence_sentences": [
#       "In addition to effective supervision of these firms, the United States needs improved tools to allow the orderly resolution of systemically important nonbank financial firms, including a mechanism to cover the costs of the resolution if government assistance is required to prevent systemic consequences.",
#       "Developing appropriate resolution procedures for potentially systemic financial firms, including bank holding companies, is a complex and challenging task that will take some time to complete."
#     ],
#     "text1_keywords": ["too-big-to-fail", "orderly resolution"],
#     "text2_keywords": ["improved tools", "resolution procedures"]
#   }
# ]
# ```
# Tokens used: 43698
# Cost of the request: $0.000087
# Response: ```json
# [
#   {
#     "dimension_title": "Concern to Action",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "Congress is appropriately concerned about problems in the mortgage market.",
#       "We share Congress's concerns with these practices."
#     ],
#     "text2_evidence_sentences": [
#       "We are engaged in an array of activities to respond to these concerns.",
#       "In DATE, we will propose new rules regarding advertising, the timing of disclosures, and practices that we find to be unfair or deceptive under our HOEPA authority, all of which we believe will offer increasing protection to consumers."
#     ],
#     "text1_keywords": ["appropriately concerned", "problems in the mortgage market"],
#     "text2_keywords": ["engaged in an array of activities", "increasing protection to consumers"]
#   },
#   {
#     "dimension_title": "Describing Problems to Implementing Solutions",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "Delinquencies and foreclosures have increased.",
#       "The recent increase in delinquencies and foreclosures has created personal, financial, and social distress for many homeowners and communities."
#     ],
#     "text2_evidence_sentences": [
#       "The Board continues to encourage servicers and investors to make every effort to keep troubled borrowers in their homes.",
#       "We have also been talking with lenders, servicers and investors, independently as well as through the Hope Now alliance, to support prudent efforts to reach out to as many borrowers as possible."
#     ],
#     "text1_keywords": ["delinquencies", "foreclosures"],
#     "text2_keywords": ["encourage servicers", "troubled borrowers"]
#   },
#   {
#     "dimension_title": "Acknowledging Complexity to Seeking Standardization",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "The regulatory scheme for the mortgage industry has become extremely complex as the breadth and depth of this market has grown over DATE and the role of nonbank mortgage lenders, particularly in the subprime market, has increased.",
#       "To achieve that balance, we coordinate with other federal and state agencies, and consult with consumer advocates, lenders, investors, and other interested parties."
#     ],
#     "text2_evidence_sentences": [
#       "More generally, the Board supports efforts by the industry and others to develop reasonable and standardized approaches to dealing with these challenges.",
#       "Such approaches, when applied consistently and predictably, can reduce uncertainty and ultimately help the markets function."
#     ],
#     "text1_keywords": ["extremely complex", "coordinate"],
#     "text2_keywords": ["standardized approaches", "reduce uncertainty"]
#   },
#   {
#     "dimension_title": "Highlighting Risks to Emphasizing Sustainability",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "These loans are recognized by the higher prices they carry, which reflect subprime lenders' decisions to seek additional compensation for the credit risk they incur.",
#       "Adjustable-rate subprime mortgages originated in DATE have performed the worst, with some of them defaulting after only one or two payments (or even no payment at all)."
#     ],
#     "text2_evidence_sentences": [
#       "We continue to work to find and implement the best and most sustainable solutions to the current challenges.",
#       "In short, we should pursue sustainable solutions."
#     ],
#     "text1_keywords": ["credit risk", "defaulting"],
#     "text2_keywords": ["sustainable solutions", "implement"]
#   },
#   {
#     "dimension_title": "Acknowledging Deterioration to Promoting Responsible Lending",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 11,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "While the expansion of the subprime mortgage market over DATE has increased access to credit, the subprime mortgage market during DATE was also accompanied by a deterioration in underwriting standards.",
#       "In some cases, abusive or fraudulent lending practices resulted in homeowners taking on mortgage obligations they could not afford, with terms they may not have fully understood."
#     ],
#     "text2_evidence_sentences": [
#       "The Board believes that responsible subprime lending has an important role to play in expanding credit to traditionally underserved borrowers.",
#       "We commend leaders in Congress who are looking into these problems and wrestling with the challenges of addressing abusive lending while encouraging responsible lending."
#     ],
#     "text1_keywords": ["deterioration", "abusive or fraudulent lending practices"],
#     "text2_keywords": ["responsible subprime lending", "encouraging responsible lending"]
#   }
# ]
# ```
# Tokens used: 38583
# Cost of the request: $0.000077
# Response: ```json
# [
#   {
#     "dimension_title": "Emphasis on Past Crises to Focus on Future Stability",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 17,
#     "confidence_score_text2": 20,
#     "text1_evidence_sentences": [
#       "A series of financial panics in DATE and DATE, most notably the Panic of DATE, revived the idea of creating a central bank to provide the nation with a safer, more flexible, and more stable monetary and financial system.",
#       "We have an all-too-recent example of the Fed as a source of financial stability in its response to the financial aftermath of the terrorist attacks of DATE, which occurred just before I joined the Board in DATE."
#     ],
#     "text2_evidence_sentences": [
#       "As severe as the effects of the crisis have been, however, the outcome could have been markedly worse without the strong actions taken by the Congress, the Treasury Department, the Federal Reserve, the Federal Deposit Insurance Corporation, and other authorities both here and abroad.",
#       "It would be a tragedy if, after all the hardships that Americans have endured during DATE, our nation failed to take the steps necessary to prevent a recurrence of a crisis of the magnitude we have recently confronted."
#     ],
#     "text1_keywords": ["financial panics", "terrorist attacks"],
#     "text2_keywords": ["prevent a recurrence", "steps necessary"]
#   },
#   {
#     "dimension_title": "Describing Independence to Asserting Independence",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 17,
#     "confidence_score_text2": 20,
#     "text1_evidence_sentences": [
#       "As I mentioned, our goals - price stability and maximum sustainable employment - are set by law, but we are afforded the political independence to make the sometimes unpopular decisions required to achieve those goals.",
#       "Appropriate transparency and accountability offer a necessary counterbalance to that independence."
#     ],
#     "text2_evidence_sentences": [
#       "Finally, I thank my colleagues throughout the Federal Reserve System for the remarkable resourcefulness, dedication, and stamina they have demonstrated over DATE under extremely trying conditions.",
#       "And, as we move forward, we must take care that the Federal Reserve remains effective and independent, with the capacity to foster financial stability and to support a return to prosperity and economic opportunity in a context of price stability."
#     ],
#     "text1_keywords": ["political independence", "transparency and accountability"],
#     "text2_keywords": ["strong and independent", "effective and independent"]
#   },
#   {
#     "dimension_title": "Acknowledging Limitations to Expressing Confidence",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 17,
#     "confidence_score_text2": 20,
#     "text1_evidence_sentences": [
#       "But while we lived through them, there was much uncertainty about the evolving structure of the economy and about the influence of monetary policy.",
#       "As a consequence, the conduct of monetary policy in the United States has come to involve, at its core, crucial elements of risk management."
#     ],
#     "text2_evidence_sentences": [
#       "We are confident that we have the necessary tools to do so.",
#       "If I am confirmed, I will work to the utmost of my abilities in the pursuit of those objectives."
#     ],
#     "text1_keywords": ["much uncertainty", "risk management"],
#     "text2_keywords": ["confident", "to the utmost of my abilities"]
#   },
#   {
#     "dimension_title": "Focus on Internal Processes to Focus on External Impact",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 17,
#     "confidence_score_text2": 20,
#     "text1_evidence_sentences": [
#       "Deciding on the appropriate policy from among the various options keeps nineteen policymakers and a staff of more than four hundred Ph.D. economists at the Board and the Reserve Banks quite busy.",
#       "After seating ourselves around the twentyseven-foot-long, polished mahogany-and-black-granite Board table, we begin punctually at TIME."
#     ],
#     "text2_evidence_sentences": [
#       "The Federal Reserve remains committed to its mission to help restore prosperity and to stimulate job creation while preserving price stability.",
#       "Critically, it allows the Federal Open Market Committee to make monetary policy in the longer-term economic interests of the American people, rather than in the service of shortterm political imperatives."
#     ],
#     "text1_keywords": ["nineteen policymakers", "Board table"],
#     "text2_keywords": ["restore prosperity", "economic interests of the American people"]
#   },
#   {
#     "dimension_title": "Emphasis on Data to Emphasis on Human Impact",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 17,
#     "confidence_score_text2": 20,
#     "text1_evidence_sentences": [
#       "The boards of the Reserve Banks also contribute a wealth of anecdotal information to supplement the torrent of hard economic data the Fed analyzes.",
#       "The Greenbook contains the staffs' summary of recent economic information, a baseline economic forecast, which is the staff's best estimate, and scenarios based on possible alternative future events."
#     ],
#     "text2_evidence_sentences": [
#       "Far too many Americans are without jobs, and unemployment could remain high for some time even if, as we anticipate, moderate economic growth continues.",
#       "It is essential that the public have the information it needs to understand and be assured of the integrity of all our operations, including all aspects of our balance sheet and our financial controls."
#     ],
#     "text1_keywords": ["hard economic data", "economic information"],
#     "text2_keywords": ["Americans are without jobs", "public have the information"]
#   }
# ]
# ```
# Tokens used: 25845
# Cost of the request: $0.000052
# Response: ```json
# [
#   {
#     "dimension_title": "Optimism to Cautious Outlook",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 66,
#     "confidence_score_text2": 50,
#     "text1_evidence_sentences": [
#       "Community banks are generally doing quite well, and I expect that good performance to continue.",
#       "The Board has long taken the view that community banks will remain a vigorous and innovative sector of the economy."
#     ],
#     "text2_evidence_sentences": [
#       "In sum, banking organizations continue to face significant challenges, and credit markets are far from fully healed.",
#       "However, the banking system remains fragile."
#     ],
#     "text1_keywords": ["good news", "vigorous and innovative"],
#     "text2_keywords": ["stresses remain", "significant challenges"]
#   },
#   {
#     "dimension_title": "Emphasis on Overall Strength to Focus on Specific Weaknesses",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "High",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 50,
#     "confidence_score_text2": 50,
#     "text1_evidence_sentences": [
#       "By a wide variety of indicators, the overall performance of community banks in DATE has been quite strong.",
#       "In my judgment, well-managed and innovative community banks will continue to play a critical role in the U.S. economy."
#     ],
#     "text2_evidence_sentences": [
#       "Higher loan losses are depleting loan loss reserves at many banking organizations, necessitating large new provisions that are producing net losses or low earnings.",
#       "These developments have raised the number of problem banks to the highest level since DATE, and the rate of bank and thrift failures has accelerated throughout DATE."
#     ],
#     "text1_keywords": ["good news", "vigorous and innovative"],
#     "text2_keywords": ["significant challenges", "fragile"]
#   },
#   {
#     "dimension_title": "Confidence in Risk Management to Concern About Risk Concentrations",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 50,
#     "confidence_score_text2": 66,
#     "text1_evidence_sentences": [
#       "Importantly, most community banks have effectively controlled the maturity distributions of their assets and made significant improvements over DATE to their management and measurement of interest rate risk.",
#       "Certainly, the procedures employed by community banks DATE are significantly more effective than those typically used as recently as DATE."
#     ],
#     "text2_evidence_sentences": [
#       "In particular, some large regional and community banking firms that have built up unprecedented concentrations in CRE loans will be particularly affected by emerging conditions in real estate markets.",
#       "These losses will place continued pressure on banks' earnings, especially those of smaller regional and community banks that have high concentrations of CRE loans."
#     ],
#     "text1_keywords": ["effectively controlled", "improvements"],
#     "text2_keywords": ["unprecedented concentrations", "continued pressure"]
#   },
#   {
#     "dimension_title": "Emphasis on Innovation to Focus on Regulatory Compliance",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 50,
#     "confidence_score_text2": 50,
#     "text1_evidence_sentences": [
#       "The Board has long taken the view that community banks will remain a vigorous and innovative sector of the economy.",
#       "In my judgment, well-managed and innovative community banks will continue to play a critical role in the U.S. economy."
#     ],
#     "text2_evidence_sentences": [
#       "We are currently in the final stages of developing interagency guidance on CRE loan restructurings and workouts.",
#       "This new guidance, which should be finalized shortly, is intended to promote prudent CRE loan workouts as banks work with their creditworthy borrowers and to ensure a balanced and consistent supervisory review of banking organizations."
#     ],
#     "text1_keywords": ["vigorous", "innovative"],
#     "text2_keywords": ["interagency guidance", "supervisory review"]
#   },
#   {
#     "dimension_title": "General Stability to Specific Concerns About Loan Quality",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "High",
#     "confidence_score_text1": 50,
#     "confidence_score_text2": 66,
#     "text1_evidence_sentences": [
#       "Various measures of loan quality for community banks have been robust, and bank failures have been rare.",
#       "Consistent with this view, community bank capital ratios remain impressively high, and community banks' ability to attract deposits continues to be a source of strength."
#     ],
#     "text2_evidence_sentences": [
#       "DATE into a substantial recession, loan quality is poor across many asset classes and, as noted earlier, continues to deteriorate as lingering weakness in housing markets affects the performance of residential mortgages and construction loans.",
#       "Higher loan losses are depleting loan loss reserves at many banking organizations, necessitating large new provisions that are producing net losses or low earnings."
#     ],
#     "text1_keywords": ["robust", "impressively high"],
#     "text2_keywords": ["poor loan quality", "loan losses"]
#   }
# ]
# ```
# Tokens used: 43506
# Cost of the request: $0.000087
# Response: ```json
# [
#   {
#     "dimension_title": "Short-Term Focus to Long-Term Focus",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 12,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "This favorable short-term outlook for the U.S. economy, however, is playing out against a backdrop of growing concern about the prospects for the federal budget.",
#       "For a time, the fiscal stimulus associated with the larger deficits was helpful in shoring up a weak economy."
#     ],
#     "text2_evidence_sentences": [
#       "However, the positive short-term economic outlook is playing out against a backdrop of concern about the prospects for the federal budget, especially over the longer run.",
#       "Crafting a budget strategy that meets the nation's longer-run needs will become ever more difficult the more we delay."
#     ],
#     "text1_keywords": ["short-term outlook", "fiscal stimulus"],
#     "text2_keywords": ["longer run", "longer-run needs"]
#   },
#   {
#     "dimension_title": "Emphasis on Rules to Emphasis on Choices",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 12,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "For DATE, the rules laid out in the Budget Enforcement Act of DATE, and the later modifications and extensions of the act, provided a procedural framework that helped the Congress make the difficult decisions that were required to forge a better fiscal balance.",
#       "However, the brief emergence of surpluses eroded the will to adhere to those rules, and many of the provisions that helped to restrain budgetary decisionmaking in the DATEs - in particular, the limits on discretionary spending and the PAYGO requirements - were violated more and more frequently and eventually allowed to expire."
#     ],
#     "text2_evidence_sentences": [
#       "The fundamental fiscal issue is the need to make difficult choices among budget priorities, and this need is becoming ever more pressing in light of the unprecedented number of individuals approaching retirement age.",
#       "No changes will be easy."
#     ],
#     "text1_keywords": ["Budget Enforcement Act", "procedural framework"],
#     "text2_keywords": ["difficult choices", "budget priorities"]
#   },
#   {
#     "dimension_title": "Implicit Optimism to Explicit Concern",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 12,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "The most recent indicators suggest that the economy is off to a strong start in DATE, and prospects for sustaining the expansion in the period ahead are good.",
#       "History has shown that, when faced with major challenges, elected officials have risen to the occasion."
#     ],
#     "text2_evidence_sentences": [
#       "However, the positive short-term economic outlook is playing out against a backdrop of concern about the prospects for the federal budget, especially over the longer run.",
#       "The likelihood of escalating unified budget deficits is of especially great concern because they would drain an inexorably growing volume of real resources away from private capital formation over time and cast an ever-larger shadow over the growth of living standards."
#     ],
#     "text1_keywords": ["strong start", "prospects", "risen to the occasion"],
#     "text2_keywords": ["concern", "especially great concern", "ever-larger shadow"]
#   },
#   {
#     "dimension_title": "General Economic Discussion to Specific Budgetary Focus",
#     "text1_sentence_count": 2,
#     "text2_sentence_count": 2,
#     "confidence_label_text1": "Medium",
#     "confidence_label_text2": "Medium",
#     "confidence_score_text1": 12,
#     "confidence_score_text2": 10,
#     "text1_evidence_sentences": [
#       "As you know, the U.S. economy appears to have made the transition from a period of subpar growth to one of more vigorous expansion.",
#       "Overall, the economy has lately made impressive gains in output and real incomes, although progress in creating jobs has been limited."
#     ],
#     "text2_evidence_sentences": [
#       "Indeed, the unified budget ran a deficit equal to about NUM-NUM/NUM percent of gross domestic product in fiscal DATE, and federal debt held by the public as a percent of GDP has risen noticeably since it bottomed out in DATE.",
#       "But, as the latest projections from the Administration and the Congressional Budget Office suggest, our budget position is unlikely to improve substantially in DATE unless major deficit-reducing actions are taken."
#     ],
#     "text1_keywords": ["U.S. economy", "vigorous expansion", "impressive gains"],
#     "text2_keywords": ["unified budget", "federal debt", "budget position"]
#   }
# ]
# ```
# Tokens used: 30078
# Cost of the request: $0.000060
